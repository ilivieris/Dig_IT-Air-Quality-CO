# %% [markdown]
# # Libraries

# %% [markdown]
# ##  Remove warnings

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import libraries

# %%
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import time
import pandas    as pd
import numpy     as np
from   tqdm      import tqdm


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot   as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow 
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *
from   tensorflow.keras.callbacks               import EarlyStopping
from   tensorflow.keras.callbacks               import ModelCheckpoint
from   tensorflow.keras.callbacks               import ReduceLROnPlateau


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# User libraries
#
from utils.PerformanceMetrics import RegressionEvaluation
from utils.plot_scatter       import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## CUDA

# %%
try:
    gpus = tensorflow.config.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)

            logical_gpus = tensorflow.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")

        except RuntimeError as e:

            # Memory growth must be set before GPUs have been initialized
            print(e)
except:
    print('[INFO] Not GPU found')

# %% [markdown]
# ## Data handling parameters

# %%
# Parameters
#
filename        = '../metadata/7-kanal-1.csv'
#
Transformation  = True
Scaling         = 'Standard'

# %% [markdown]
# ## Neural networks parameters

# %%
Lag        =   12
Horizon    =    4
#
epochs     =  200
batch_size =   32

# %% [markdown]
# # Data handling

# %% [markdown]
# ## Import data

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.35 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# ### Set index

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)


df = df.resample('5min').mean().interpolate()
# df = pd.DataFrame( df[['Temperature', 'Humidity', 'NO2', 'CO']] )
df = pd.DataFrame( df[['NO2', 'CO']] )
# df = pd.DataFrame( df[ 'CO' ] )


df.head(3)
# Out:
#                             NO2          CO
# Date
# 2022-02-19 00:00:00  186.210526  248.947368
# 2022-02-19 00:05:00  151.052632  232.473684
# 2022-02-19 00:10:00  135.315789  226.947368

# %%
targetSeries = df.columns[-1]

# %% [markdown]
# ### Include MA-based features

# %%
# df['MA6']  = df[ targetSeries ].rolling(6).mean()
# df['MA12'] = df[ targetSeries ].rolling(12).mean()

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %% [markdown]
# ### Visualization

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(20, 3) )

df_train[ targetSeries ].plot(ax=ax, color='tab:blue' )
df_test[ targetSeries ].plot(ax=ax,  color='tab:orange')

plt.legend(['Training', 'Testing'], frameon = False, fontsize = 14)
plt.ylabel(targetSeries, size = 14)
plt.xlabel('Date', size = 14);
plt.xticks(size = 12);
plt.yticks(size = 12);

# %% [markdown]
# ### Fixing Lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = max(df.min().min(), 1.0)
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %%
if (Scaling == 'MinMax'):
    print('[INFO] Scaling: MinMax')
    
    for feature in df.columns:
        if (feature == targetSeries): continue
        print('Feature: ', feature)        
        # Set scaler
        #
        scaler = MinMaxScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = MinMaxScaler()
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
            
elif (Scaling == 'Robust'):
    print('[INFO] Scaling: Robust')
    
    for feature in df.columns:
        if (feature == targetSeries): continue
        print('Feature: ', feature)        
        # Set scaler
        #
        scaler = RobustScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = RobustScaler()
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
        
elif (Scaling == 'Standard'):
    print('[INFO] Scaling: Standard')

    for feature in df.columns:
        if (feature == targetSeries): continue
        print('Feature: ', feature)
        # Set scaler
        #
        scaler = StandardScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = StandardScaler()
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
           
else:
    print('[WARNING] Unknown data scaling. Standar scaling was selected')   
    
    for feature in df.columns:
        if (feature == targetSeries): continue
        print('Feature: ', feature)
        # Set scaler
        #
        scaler = StandardScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = StandardScaler()
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
# Out:
# [INFO] Scaling: Standard
# Feature:  NO2

# %% [markdown]
# ## Create Training/Testing data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, overlap = 1, includeDate = False):
    
    if (targetSeries is None):
        print('[INFO] Target series is not defined')
        return (None, None, None)
    
    dataX, CurrentValue, dataY = [], [], []
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):

        # Instances: Lag-d differences
        Instance  = (df.iloc[i+Lag-1] - df.iloc[i:(i+Lag-1)]).to_numpy().tolist() 
        
        # Include date info
        if (includeDate):            
            myDate = [ np.sin(df[i:(i+Lag-1)].index.hour + df[i:(i+Lag-1)].index.minute / 60 ).tolist(), 
                       np.cos(df[i:(i+Lag-1)].index.hour + df[i:(i+Lag-1)].index.minute / 60 ).tolist() ]
            myDate = np.asarray( myDate ).T
            #
            Instance = np.concatenate([Instance, myDate], axis = -1)

        # Current value
        CurrentValue.append( df[ targetSeries ].to_numpy()[i+Lag-1] )
        # Append instance
        dataX.append( Instance ) 
                
        # Target Instance
        Instance = (df[ targetSeries ][i+Lag-1] - df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon])
        # Append instance
        dataY.append( Instance )

        
    return ( np.array(dataX), np.array(dataY), np.array(CurrentValue) )

# %%
trainX, trainY, _                = create_dataset(df           = df_train, 
                                                  Lag          = Lag, 
                                                  Horizon      = Horizon, 
                                                  targetSeries = targetSeries,
                                                  includeDate  = False,
                                                  overlap      = Horizon,)

testX,  testY, test_CurrentValue = create_dataset(df           = df_test, 
                                                  Lag          = Lag, 
                                                  Horizon      = Horizon, 
                                                  targetSeries = targetSeries,
                                                  includeDate  = False,                                                
                                                  overlap      = 1)


# trainX = np.expand_dims(trainX, axis=-1)
# testX  = np.expand_dims(testX, axis=-1)
print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4276/4276 [00:02<00:00, 2133.35it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4277/4277 [00:02<00:00, 2068.84it/s]
# Training instances:     4276
# Testing instances:      4277

# %%
trainX.shape, testY.shape
# Out:
# ((4276, 11, 2), (4277, 4))

# %% [markdown]
# # Forecasting model: NBeats

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## Setup model

# %%
from utils.NBeats_Keras import NBeatsNet


model = NBeatsNet(stack_types            = (NBeatsNet.GENERIC_BLOCK, NBeatsNet.GENERIC_BLOCK),
                  input_dim              = trainX.shape[2],
                  forecast_length        = Horizon, 
                  backcast_length        = trainX.shape[1], # Lag-1
                  hidden_layer_units     = 128,
                  nb_blocks_per_stack    = 4,
                  share_weights_in_stack = False,
                  activation_function    = 'relu')
# Out:
# 2022-05-11 13:48:35.070300: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Training parameters

# %%
# Define metrics
#
metrics = [
            MeanAbsoluteError(name = "MAE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]


model.compile(loss      = 'mse', 
              optimizer = Adam(learning_rate = 5.e-4), 
              metrics   = metrics)

# %%
# Checkpoint
#
checkpoint = ModelCheckpoint("models/NBeats_Diff.hdf5", 
                              monitor        = 'val_loss', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 20)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_loss', 
                                   factor      = 0.5,
                                   patience    = 10)

# %% [markdown]
# ## Training process

# %%
# Start clock
#
start = time.time()


score = model.fit(trainX, trainY, 
                  epochs          = epochs, 
                  batch_size      = batch_size, 
                  callbacks       = [checkpoint, earlystopping, lrs_scheduler],
                  verbose         = True, 
                  shuffle         = True,
                  validation_data = (testX, testY))


# Terminate clock
#
stop = time.time()
print('[INFO] Time %.2f' % (stop - start))
# Out:
# Epoch 1/200
# 134/134 [==============================] - 7s 24ms/step - loss: 0.1834 - MAE: 0.2696 - RMSE: 0.4283 - val_loss: 0.3385 - val_MAE: 0.3648 - val_RMSE: 0.5818 - lr: 5.0000e-04
# Epoch 2/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1796 - MAE: 0.2681 - RMSE: 0.4238 - val_loss: 0.3356 - val_MAE: 0.3599 - val_RMSE: 0.5793 - lr: 5.0000e-04
# Epoch 3/200
# 134/134 [==============================] - 3s 19ms/step - loss: 0.1784 - MAE: 0.2674 - RMSE: 0.4223 - val_loss: 0.3269 - val_MAE: 0.3578 - val_RMSE: 0.5717 - lr: 5.0000e-04
# Epoch 4/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1766 - MAE: 0.2662 - RMSE: 0.4202 - val_loss: 0.3357 - val_MAE: 0.3612 - val_RMSE: 0.5794 - lr: 5.0000e-04
# Epoch 5/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1763 - MAE: 0.2662 - RMSE: 0.4198 - val_loss: 0.3315 - val_MAE: 0.3618 - val_RMSE: 0.5757 - lr: 5.0000e-04
# Epoch 6/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1753 - MAE: 0.2659 - RMSE: 0.4187 - val_loss: 0.3300 - val_MAE: 0.3553 - val_RMSE: 0.5744 - lr: 5.0000e-04
# Epoch 7/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1749 - MAE: 0.2659 - RMSE: 0.4182 - val_loss: 0.3274 - val_MAE: 0.3570 - val_RMSE: 0.5722 - lr: 5.0000e-04
# Epoch 8/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1736 - MAE: 0.2648 - RMSE: 0.4166 - val_loss: 0.3301 - val_MAE: 0.3593 - val_RMSE: 0.5746 - lr: 5.0000e-04
# Epoch 9/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1744 - MAE: 0.2656 - RMSE: 0.4177 - val_loss: 0.3287 - val_MAE: 0.3557 - val_RMSE: 0.5734 - lr: 5.0000e-04
# Epoch 10/200
# 134/134 [==============================] - 2s 17ms/step - loss: 0.1735 - MAE: 0.2654 - RMSE: 0.4165 - val_loss: 0.3246 - val_MAE: 0.3580 - val_RMSE: 0.5698 - lr: 5.0000e-04
# Epoch 11/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.1737 - MAE: 0.2652 - RMSE: 0.4168 - val_loss: 0.3311 - val_MAE: 0.3589 - val_RMSE: 0.5754 - lr: 5.0000e-04
# Epoch 12/200
# 134/134 [==============================] - 2s 17ms/step - loss: 0.1743 - MAE: 0.2657 - RMSE: 0.4175 - val_loss: 0.3245 - val_MAE: 0.3544 - val_RMSE: 0.5696 - lr: 5.0000e-04
# Epoch 13/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1738 - MAE: 0.2649 - RMSE: 0.4169 - val_loss: 0.3261 - val_MAE: 0.3568 - val_RMSE: 0.5711 - lr: 5.0000e-04
# Epoch 14/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1730 - MAE: 0.2661 - RMSE: 0.4159 - val_loss: 0.3255 - val_MAE: 0.3555 - val_RMSE: 0.5706 - lr: 5.0000e-04
# Epoch 15/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1721 - MAE: 0.2651 - RMSE: 0.4148 - val_loss: 0.3252 - val_MAE: 0.3572 - val_RMSE: 0.5703 - lr: 5.0000e-04
# Epoch 16/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1726 - MAE: 0.2647 - RMSE: 0.4155 - val_loss: 0.3232 - val_MAE: 0.3586 - val_RMSE: 0.5685 - lr: 5.0000e-04
# Epoch 17/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.1719 - MAE: 0.2648 - RMSE: 0.4146 - val_loss: 0.3239 - val_MAE: 0.3554 - val_RMSE: 0.5691 - lr: 5.0000e-04
# Epoch 18/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1719 - MAE: 0.2645 - RMSE: 0.4146 - val_loss: 0.3259 - val_MAE: 0.3564 - val_RMSE: 0.5709 - lr: 5.0000e-04
# Epoch 19/200
# 134/134 [==============================] - 2s 11ms/step - loss: 0.1718 - MAE: 0.2640 - RMSE: 0.4145 - val_loss: 0.3267 - val_MAE: 0.3552 - val_RMSE: 0.5716 - lr: 5.0000e-04
# Epoch 20/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1720 - MAE: 0.2655 - RMSE: 0.4147 - val_loss: 0.3255 - val_MAE: 0.3557 - val_RMSE: 0.5705 - lr: 5.0000e-04
# Epoch 21/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1714 - MAE: 0.2641 - RMSE: 0.4141 - val_loss: 0.3236 - val_MAE: 0.3549 - val_RMSE: 0.5689 - lr: 5.0000e-04
# Epoch 22/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.1713 - MAE: 0.2644 - RMSE: 0.4138 - val_loss: 0.3247 - val_MAE: 0.3581 - val_RMSE: 0.5699 - lr: 5.0000e-04
# Epoch 23/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.1711 - MAE: 0.2635 - RMSE: 0.4137 - val_loss: 0.3232 - val_MAE: 0.3568 - val_RMSE: 0.5685 - lr: 5.0000e-04
# Epoch 24/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1707 - MAE: 0.2641 - RMSE: 0.4132 - val_loss: 0.3228 - val_MAE: 0.3560 - val_RMSE: 0.5682 - lr: 5.0000e-04
# Epoch 25/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1712 - MAE: 0.2637 - RMSE: 0.4138 - val_loss: 0.3242 - val_MAE: 0.3568 - val_RMSE: 0.5693 - lr: 5.0000e-04
# Epoch 26/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1701 - MAE: 0.2638 - RMSE: 0.4124 - val_loss: 0.3286 - val_MAE: 0.3606 - val_RMSE: 0.5732 - lr: 5.0000e-04
# Epoch 27/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.1712 - MAE: 0.2640 - RMSE: 0.4137 - val_loss: 0.3241 - val_MAE: 0.3571 - val_RMSE: 0.5693 - lr: 5.0000e-04
# Epoch 28/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.1693 - MAE: 0.2633 - RMSE: 0.4114 - val_loss: 0.3259 - val_MAE: 0.3563 - val_RMSE: 0.5709 - lr: 5.0000e-04
# Epoch 29/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1701 - MAE: 0.2630 - RMSE: 0.4125 - val_loss: 0.3244 - val_MAE: 0.3593 - val_RMSE: 0.5695 - lr: 5.0000e-04
# Epoch 30/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1699 - MAE: 0.2629 - RMSE: 0.4122 - val_loss: 0.3245 - val_MAE: 0.3623 - val_RMSE: 0.5696 - lr: 5.0000e-04
# Epoch 31/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.1706 - MAE: 0.2644 - RMSE: 0.4131 - val_loss: 0.3234 - val_MAE: 0.3558 - val_RMSE: 0.5687 - lr: 5.0000e-04
# Epoch 32/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1699 - MAE: 0.2623 - RMSE: 0.4121 - val_loss: 0.3263 - val_MAE: 0.3584 - val_RMSE: 0.5713 - lr: 5.0000e-04
# Epoch 33/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1700 - MAE: 0.2629 - RMSE: 0.4123 - val_loss: 0.3237 - val_MAE: 0.3597 - val_RMSE: 0.5690 - lr: 5.0000e-04
# Epoch 34/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.1705 - MAE: 0.2627 - RMSE: 0.4129 - val_loss: 0.3257 - val_MAE: 0.3591 - val_RMSE: 0.5707 - lr: 5.0000e-04
# Epoch 35/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1675 - MAE: 0.2619 - RMSE: 0.4092 - val_loss: 0.3252 - val_MAE: 0.3572 - val_RMSE: 0.5702 - lr: 2.5000e-04
# Epoch 36/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.1666 - MAE: 0.2609 - RMSE: 0.4082 - val_loss: 0.3266 - val_MAE: 0.3589 - val_RMSE: 0.5714 - lr: 2.5000e-04
# Epoch 37/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1662 - MAE: 0.2608 - RMSE: 0.4076 - val_loss: 0.3235 - val_MAE: 0.3574 - val_RMSE: 0.5688 - lr: 2.5000e-04
# Epoch 38/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1657 - MAE: 0.2613 - RMSE: 0.4071 - val_loss: 0.3564 - val_MAE: 0.3731 - val_RMSE: 0.5970 - lr: 2.5000e-04
# Epoch 39/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.1670 - MAE: 0.2606 - RMSE: 0.4087 - val_loss: 0.3249 - val_MAE: 0.3596 - val_RMSE: 0.5700 - lr: 2.5000e-04
# Epoch 40/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1650 - MAE: 0.2607 - RMSE: 0.4062 - val_loss: 0.3249 - val_MAE: 0.3596 - val_RMSE: 0.5700 - lr: 2.5000e-04
# Epoch 41/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1643 - MAE: 0.2600 - RMSE: 0.4054 - val_loss: 0.3296 - val_MAE: 0.3609 - val_RMSE: 0.5741 - lr: 2.5000e-04
# Epoch 42/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1643 - MAE: 0.2594 - RMSE: 0.4053 - val_loss: 0.3271 - val_MAE: 0.3598 - val_RMSE: 0.5719 - lr: 2.5000e-04
# Epoch 43/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1638 - MAE: 0.2591 - RMSE: 0.4048 - val_loss: 0.3251 - val_MAE: 0.3582 - val_RMSE: 0.5702 - lr: 2.5000e-04
# Epoch 44/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1635 - MAE: 0.2598 - RMSE: 0.4044 - val_loss: 0.3321 - val_MAE: 0.3599 - val_RMSE: 0.5763 - lr: 2.5000e-04
# Epoch 00044: early stopping
# [INFO] Time 87.46

# %%
# Create figure
#
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 3) )

# Plot RMSE
#
ax[0].plot( score.history['RMSE'], marker = 'o');
ax[0].plot( score.history['val_RMSE'], marker = 'o');
ax[0].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[0].set_title('RMSE');

# Plot RMSE
#
ax[1].plot( score.history['MAE'], marker = 'o');
ax[1].plot( score.history['val_MAE'], marker = 'o');
ax[1].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[1].set_title('MAE');

# %% [markdown]
# ## Load optimized model

# %%
# Load the best model
#
model.load_weights('models/NBeats_Diff.hdf5')

print('[INFO] Model loaded')
# Out:
# [INFO] Model loaded

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Get predictions

# %%
# Get predictions
#
pred = model.predict( testX )

pred = pred.squeeze(-1)

# %% [markdown]
# ### Inverse "Lag-d Diff" transformation

# %%
for i in range( Horizon ):
    testY[:, i] = test_CurrentValue - testY[:, i]
    pred[:, i]  = test_CurrentValue - pred[:, i]

# %% [markdown]
# ### Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred  = np.exp( pred )  - VALUE

# %% [markdown]
# ### Calculate Performance on Testing set - Prediction visualization

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices['Real']       = testY[:,  i]
    Prices['Prediction'] = pred[:, i] 



    # Evaluation
    #
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Prices )

    # Store results
    #
    Performance_Foresting_Model['RMSE']    += [ RMSE  ]
    Performance_Foresting_Model['MAE']     += [ MAE   ]
    Performance_Foresting_Model['SMAPE']   += [ SMAPE ]
    Performance_Foresting_Model['R2']      += [ R2    ]

#     # Present results
#     #
#     print('Horizon: ', i+1)
#     print('> MAE:   ', MAE)
#     print('> RMSE:  ', RMSE)
#     print('> SMAPE: ', SMAPE)
#     print('> R2:    ', R2)
#     print()
    
    print('Horizon: %2i MAE %5.2f SMAPE: %5.2f R2: %.2f' % (i+1, MAE, SMAPE, R2) )
# Out:
# [INFO] Feature:  CO
# ------------------------------------------------
# Horizon:  1 MAE  9.76 SMAPE:  4.72 R2: 0.94
# Horizon:  2 MAE 17.16 SMAPE:  8.30 R2: 0.81
# Horizon:  3 MAE 22.07 SMAPE: 10.72 R2: 0.69
# Horizon:  4 MAE 26.25 SMAPE: 12.78 R2: 0.58

# %%
# CO - Log+StandardScaler
# ------------------------------------------------
# Horizon:  1 MAE  9.71 SMAPE:  4.72 R2: 0.94
# Horizon:  2 MAE 17.19 SMAPE:  8.34 R2: 0.81
# Horizon:  3 MAE 22.22 SMAPE: 10.82 R2: 0.69
# Horizon:  4 MAE 26.44 SMAPE: 12.91 R2: 0.58


# CO + NO2 - Log+StandardScaler
# ------------------------------------------------
# Horizon:  1 MAE  9.76 SMAPE:  4.72 R2: 0.94
# Horizon:  2 MAE 17.16 SMAPE:  8.30 R2: 0.81
# Horizon:  3 MAE 22.07 SMAPE: 10.72 R2: 0.69
# Horizon:  4 MAE 26.25 SMAPE: 12.78 R2: 0.58


# All data - Log+StandardScaler
# ------------------------------------------------
# Horizon:  1 MAE  9.87 SMAPE:  4.77 R2: 0.94
# Horizon:  2 MAE 17.22 SMAPE:  8.33 R2: 0.81
# Horizon:  3 MAE 22.13 SMAPE: 10.75 R2: 0.69
# Horizon:  4 MAE 26.33 SMAPE: 12.84 R2: 0.58

# %% [markdown]
# ## Visualization

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices['Real']       = testY[:,  i]
    Prices['Prediction'] = pred[:, i] 
            
    
    # Plot Real & Predicted values
    #
    Prices[:100].plot( figsize = (20, 3), marker = 'o' )
    #
    plt.title('Feature: {} - Horizon = {}'.format(targetSeries, i+1))
    plt.legend( frameon = False, fontsize = 14)
    plt.xticks(size = 12)
    plt.yticks(size = 12)
    plt.show()
# Out:
# [INFO] Feature:  CO
# ------------------------------------------------

# %% [markdown]
# ## Residual analysis

# %%
print('[INFO] Feature: ', targetSeries)
print(50 * '-')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices['Real']       = testY[:,  i]
    Prices['Prediction'] = pred[:, i] 


            
    from scipy import stats
    from statsmodels.graphics.tsaplots import plot_acf
    
    res = (Prices['Prediction'] - Prices['Real']).to_numpy()
    
    fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

    ax[0].hist( res, bins = 100 )    
    plot_acf( res, ax=ax[1] )
# Out:
# [INFO] Feature:  CO
# --------------------------------------------------

# %% [markdown]
# ## Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]
RandomInstances = [913, 205, 2254, 2007, 1829, 1144, 840, 713, 3457]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    #
    plt.plot(range(Lag, Lag + Horizon), testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(range(Lag, Lag + Horizon), pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Instance', 'Future values', 'Prediction'], frameon = False, fontsize = 12)
plt.show()

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame( [] )


Outputs[ targetSeries ] = testY.flatten()
Outputs['NBeats_diff'] = pred.flatten()

Outputs.to_csv('Predictions/NBeats_diff.csv')
