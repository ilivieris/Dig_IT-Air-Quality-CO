# %% [markdown]
# # Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# import tensorflow as tf
# tf.config.experimental_run_functions_eagerly(True)
# tf.keras.backend.set_floatx('float64')

# import tensorflow.python.util.deprecation as deprecation
# deprecation._PRINT_DEPRECATION_WARNINGS = False

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import math
import time
import timeit
from   tqdm    import tqdm
import pandas  as pd
import numpy   as np


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot                        as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import EarlyStopping
from   tensorflow.keras.callbacks               import ModelCheckpoint
from   tensorflow.keras.callbacks               import ReduceLROnPlateau
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from utils.PerformanceMetrics import RegressionEvaluation


print('[INFO] Libraries imported')
# Out:
# [INFO] Libraries imported

# %% [markdown]
# # Parameters

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## CUDA

# %%
try:
    gpus = tensorflow.config.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)

            logical_gpus = tensorflow.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")

        except RuntimeError as e:

            # Memory growth must be set before GPUs have been initialized
            print(e)
except:
    print('[INFO] Not GPU found')

# %% [markdown]
# ## Training paramers

# %%
Lag        =   12
Horizon    =   4
#
epochs     =  200
batch_size =   32

Transformation = True

# %% [markdown]
# # Importing data

# %%
# Parameters
#
filename   = '../metadata/7-kanal-1.csv'

Transformation  = True
Scaling         = 'Standard'

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.29 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %% [markdown]
# ## Preprocess

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)



df = df.resample('5min').mean().interpolate()
df = pd.DataFrame( df[ ['CO'] ] )
# df = pd.DataFrame( df[ ['NO2', 'CO'] ] )
# df = pd.DataFrame( df[ ['Temperature', 'Humidity', 'NO2', 'CO'] ] )


df.head(3)
# Out:
#                              CO
# Date
# 2022-02-19 00:00:00  248.947368
# 2022-02-19 00:05:00  232.473684
# 2022-02-19 00:10:00  226.947368

# %%
targetSeries = df.columns[-1]

# %% [markdown]
# ## Include MA-based features

# %%
# df['MA6']  = df[ targetSeries ].rolling(6).mean()
# df['MA12'] = df[ targetSeries ].rolling(12).mean()

# df['Hour'] = df.index.hour

# %% [markdown]
# ## Split Training/Testing set

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %%
print('Training: ', df_train.shape[0])
print('Testing:  ', df_test.shape[0])
# Out:
# Training:  17116
# Testing:   4280

# %% [markdown]
# ## Visualize Training & Testing data

# %%
plt.figure( figsize = (20, 4) );
#
df_train[ targetSeries ].plot()
df_test[ targetSeries ].plot()
#
plt.legend(['Training', 'Validation', 'Testing'], fontsize = 12);
plt.ylabel( targetSeries, size = 12);
plt.xlabel( 'Time', size = 12);

# %% [markdown]
# ## Fix lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Contruction of fitting data for training a forecasting model

# %% [markdown]
# ### Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = np.ceil( max(-df.min().min(), 1.0) )
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ### Data scaling

# %%
for feature in df_train.columns:
    if (feature == targetSeries): continue

    # Setup scaler
    #
    scaler = StandardScaler()

    # Performing Scaling - for each feature
    df_train[feature] = scaler.fit_transform( df_train[feature].to_numpy().reshape(-1,1) )
    df_test[feature]  = scaler.transform( df_test[feature].to_numpy().reshape(-1,1) )


# Setup scaler
#
scaler = StandardScaler()

df_train[targetSeries] = scaler.fit_transform( df_train[targetSeries].to_numpy().reshape(-1,1) )
df_test[targetSeries]  = scaler.transform( df_test[targetSeries].to_numpy().reshape(-1,1) )

# %% [markdown]
# ### Include date/time features

# %%
# df_train['Time (sin)'] = np.sin( df_train.index.hour + df_train.index.minute / 60 )
# df_train['Time (cos)'] = np.cos( df_train.index.hour + df_train.index.minute / 60 )
# #
# df_test['Time (sin)']  = np.sin( df_test.index.hour + df_test.index.minute / 60 )
# df_test['Time (cos)']  = np.cos( df_test.index.hour + df_test.index.minute / 60 )

# %% [markdown]
# ### Create fitting data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, overlap = 1):
    
    if (targetSeries is None):
        targetSeries = df.columns[-1]
    
    dataX, dataY = [], []
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):
        
        dataX.append( df.to_numpy()[i:(i+Lag)] )        
        dataY.append( df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon] )
        
        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df           = df_train, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = Horizon)
                               

testX,  testY  = create_dataset(df           = df_test, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = 1)


print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4276/4276 [00:00<00:00, 114429.28it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4277/4277 [00:00<00:00, 115913.71it/s]
# Training instances:     4276
# Testing instances:      4277

# %%
trainX.shape, trainY.shape
# Out:
# ((4276, 12, 1), (4276, 4))

# %% [markdown]
# # Forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsolutePercentageError(name = "MAPE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]
# Out:
# 2022-05-11 13:17:59.597816: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.models                  import *
# Inputs
#
Inputs = Input(shape = (trainX.shape[1], trainX.shape[2]))


# Encoder
#
Encoder = LSTM(units = 100, activation='relu')( Inputs )
# Decoder
#
Decoder = RepeatVector( Horizon )(Encoder)
#
Decoder = LSTM(units = 100, activation='relu')(Decoder)

# Output
#
# Outputs =  TimeDistributed(Dense(1, activation='linear'))( Decoder )
Outputs =  Dense( Horizon, activation='linear' )( Decoder )


# Create model
#
model = Model(inputs = Inputs, outputs = Outputs)

# %% [markdown]
# ## Training forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsoluteError(name = "MAE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]


model.compile(loss      = 'mse', 
              optimizer = Adam(learning_rate = 5.e-4), 
              metrics   = metrics)

# %%
# Checkpoint
#
checkpoint = ModelCheckpoint("models/Seq2Seq_LSTM.hdf5", 
                              monitor        = 'val_loss', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 10)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_loss', 
                                   factor      = 0.5,
                                   patience    = 5)

# %%
# Start clock
#
start = timeit.default_timer()


score = model.fit(trainX, trainY, 
                  epochs          = epochs, 
                  batch_size      = batch_size, 
                  callbacks       = [checkpoint, earlystopping, lrs_scheduler],
                  verbose         = 1, 
                  shuffle         = True,
                  validation_data = (testX, testY))


# Terminate clock
#
stop = timeit.default_timer()
# Out:
# Epoch 1/200
# 134/134 [==============================] - 3s 11ms/step - loss: 0.4229 - MAE: 0.4883 - RMSE: 0.6503 - val_loss: 0.4889 - val_MAE: 0.5153 - val_RMSE: 0.6992 - lr: 5.0000e-04
# Epoch 2/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.2084 - MAE: 0.3185 - RMSE: 0.4565 - val_loss: 0.4324 - val_MAE: 0.4378 - val_RMSE: 0.6575 - lr: 5.0000e-04
# Epoch 3/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1919 - MAE: 0.3015 - RMSE: 0.4381 - val_loss: 0.3457 - val_MAE: 0.4004 - val_RMSE: 0.5880 - lr: 5.0000e-04
# Epoch 4/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1820 - MAE: 0.2890 - RMSE: 0.4267 - val_loss: 0.3424 - val_MAE: 0.3839 - val_RMSE: 0.5851 - lr: 5.0000e-04
# Epoch 5/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1792 - MAE: 0.2864 - RMSE: 0.4233 - val_loss: 0.3628 - val_MAE: 0.3919 - val_RMSE: 0.6023 - lr: 5.0000e-04
# Epoch 6/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1830 - MAE: 0.2918 - RMSE: 0.4277 - val_loss: 0.3472 - val_MAE: 0.4061 - val_RMSE: 0.5892 - lr: 5.0000e-04
# Epoch 7/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1754 - MAE: 0.2810 - RMSE: 0.4188 - val_loss: 0.3206 - val_MAE: 0.3746 - val_RMSE: 0.5662 - lr: 5.0000e-04
# Epoch 8/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1766 - MAE: 0.2845 - RMSE: 0.4202 - val_loss: 0.3338 - val_MAE: 0.3771 - val_RMSE: 0.5778 - lr: 5.0000e-04
# Epoch 9/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1746 - MAE: 0.2811 - RMSE: 0.4178 - val_loss: 0.3368 - val_MAE: 0.3770 - val_RMSE: 0.5804 - lr: 5.0000e-04
# Epoch 10/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1708 - MAE: 0.2756 - RMSE: 0.4133 - val_loss: 0.3237 - val_MAE: 0.3756 - val_RMSE: 0.5689 - lr: 5.0000e-04
# Epoch 11/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1715 - MAE: 0.2762 - RMSE: 0.4141 - val_loss: 0.3298 - val_MAE: 0.3770 - val_RMSE: 0.5743 - lr: 5.0000e-04
# Epoch 12/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1687 - MAE: 0.2742 - RMSE: 0.4108 - val_loss: 0.3325 - val_MAE: 0.3710 - val_RMSE: 0.5766 - lr: 5.0000e-04
# Epoch 13/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1678 - MAE: 0.2722 - RMSE: 0.4097 - val_loss: 0.3268 - val_MAE: 0.3696 - val_RMSE: 0.5717 - lr: 2.5000e-04
# Epoch 14/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1662 - MAE: 0.2700 - RMSE: 0.4076 - val_loss: 0.3199 - val_MAE: 0.3711 - val_RMSE: 0.5656 - lr: 2.5000e-04
# Epoch 15/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1659 - MAE: 0.2690 - RMSE: 0.4073 - val_loss: 0.3305 - val_MAE: 0.3701 - val_RMSE: 0.5749 - lr: 2.5000e-04
# Epoch 16/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1658 - MAE: 0.2704 - RMSE: 0.4072 - val_loss: 0.3258 - val_MAE: 0.3745 - val_RMSE: 0.5708 - lr: 2.5000e-04
# Epoch 17/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1659 - MAE: 0.2695 - RMSE: 0.4073 - val_loss: 0.3367 - val_MAE: 0.3758 - val_RMSE: 0.5802 - lr: 2.5000e-04
# Epoch 18/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1661 - MAE: 0.2707 - RMSE: 0.4075 - val_loss: 0.3272 - val_MAE: 0.3730 - val_RMSE: 0.5721 - lr: 2.5000e-04
# Epoch 19/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1646 - MAE: 0.2681 - RMSE: 0.4057 - val_loss: 0.3183 - val_MAE: 0.3710 - val_RMSE: 0.5642 - lr: 2.5000e-04
# Epoch 20/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1651 - MAE: 0.2702 - RMSE: 0.4064 - val_loss: 0.3149 - val_MAE: 0.3792 - val_RMSE: 0.5612 - lr: 2.5000e-04
# Epoch 21/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1663 - MAE: 0.2718 - RMSE: 0.4078 - val_loss: 0.3236 - val_MAE: 0.3694 - val_RMSE: 0.5689 - lr: 2.5000e-04
# Epoch 22/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1652 - MAE: 0.2695 - RMSE: 0.4065 - val_loss: 0.3179 - val_MAE: 0.3710 - val_RMSE: 0.5638 - lr: 2.5000e-04
# Epoch 23/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1645 - MAE: 0.2677 - RMSE: 0.4056 - val_loss: 0.3178 - val_MAE: 0.3860 - val_RMSE: 0.5637 - lr: 2.5000e-04
# Epoch 24/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1648 - MAE: 0.2697 - RMSE: 0.4060 - val_loss: 0.3446 - val_MAE: 0.3791 - val_RMSE: 0.5870 - lr: 2.5000e-04
# Epoch 25/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1647 - MAE: 0.2686 - RMSE: 0.4058 - val_loss: 0.3181 - val_MAE: 0.3878 - val_RMSE: 0.5640 - lr: 2.5000e-04
# Epoch 26/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1633 - MAE: 0.2669 - RMSE: 0.4041 - val_loss: 0.3163 - val_MAE: 0.3683 - val_RMSE: 0.5624 - lr: 1.2500e-04
# Epoch 27/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1637 - MAE: 0.2675 - RMSE: 0.4046 - val_loss: 0.3201 - val_MAE: 0.3713 - val_RMSE: 0.5657 - lr: 1.2500e-04
# Epoch 28/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1636 - MAE: 0.2675 - RMSE: 0.4045 - val_loss: 0.3206 - val_MAE: 0.3710 - val_RMSE: 0.5662 - lr: 1.2500e-04
# Epoch 29/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1635 - MAE: 0.2669 - RMSE: 0.4043 - val_loss: 0.3204 - val_MAE: 0.3701 - val_RMSE: 0.5661 - lr: 1.2500e-04
# Epoch 30/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1632 - MAE: 0.2676 - RMSE: 0.4040 - val_loss: 0.3239 - val_MAE: 0.3901 - val_RMSE: 0.5691 - lr: 1.2500e-04
# Epoch 00030: early stopping

# %%
# Create figure
#
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 3) )

# Plot RMSE
#
ax[0].plot( score.history['RMSE'], marker = 'o');
ax[0].plot( score.history['val_RMSE'], marker = 'o');
ax[0].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[0].set_title('RMSE');

# Plot RMSE
#
ax[1].plot( score.history['MAE'], marker = 'o');
ax[1].plot( score.history['val_MAE'], marker = 'o');
ax[1].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[1].set_title('MAE');

# %% [markdown]
# ## Load optimized forecasting model

# %%
# Load the best model
#
model.load_weights('models/Seq2Seq_LSTM.hdf5')

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Get predictions

# %%
# Get predictions
#
pred = model.predict( testX )

# %% [markdown]
# ## Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred = np.exp( pred )   - VALUE

# %% [markdown]
# ## Visualization of predictions

# %%
Results = dict()

for i in range( Horizon ):
    Prices = pd.DataFrame( [] )

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]
    

        
    # Store results
    #
    Results[ 'Horizon {}'.format(i+1) ] = Prices

    
    
    
    # Plot results
    #
    plt.figure( figsize = (20, 4) );
    #
    Prices[ targetSeries ][:100].plot(color = 'tab:blue', marker = 'o')
    Prices[ 'Prediction' ][:100].plot(color = 'tab:orange', marker = 'o')
    
    #
    #
    plt.legend([targetSeries, 'Prediction'], fontsize = 12, frameon=False);
    plt.ylabel(targetSeries, size = 12 );
    plt.xlabel('Time', size = 12);
    plt.show()

# %% [markdown]
# ## Regression evaluation

# %%
sResults = {'MAE': [], 'RMSE': [], 'MAPE': [], 'SMAPE': [], 'R2': []}

for i in range(Horizon):
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Results['Horizon {}'.format(i+1)] )
    
    sResults['MAE']   += [MAE]
    sResults['RMSE']  += [RMSE]
    sResults['MAPE']  += [MAPE]
    sResults['SMAPE'] += [SMAPE]
    sResults['R2']    += [R2]
    
    
#     print('Horizon -%i-' % (i+1))
#     print('--------------')
#     print('MAE   = %.3f' % MAE)
#     print('RMSE  = %.3f' % RMSE)
#     print('MAPE  = %.3f' % MAPE)
#     print('SMAPE = %.3f' % SMAPE)
#     print('R2    = %.3f' % R2)
#     print()
    print('Horizon: %2i MAE %5.2f SMAPE: %5.2f R2: %.2f' %(i+1, MAE, SMAPE, R2) )
# Out:
# Horizon:  1 MAE 10.48 SMAPE:  5.21 R2: 0.94
# Horizon:  2 MAE 17.96 SMAPE:  8.86 R2: 0.81
# Horizon:  3 MAE 22.88 SMAPE: 11.35 R2: 0.71
# Horizon:  4 MAE 26.97 SMAPE: 13.43 R2: 0.61

# %%
# CO - Log+StandarScaler
# --------------------------------------------------
# Horizon:  1 MAE 10.48 SMAPE:  5.21 R2: 0.94
# Horizon:  2 MAE 17.96 SMAPE:  8.86 R2: 0.81
# Horizon:  3 MAE 22.88 SMAPE: 11.35 R2: 0.71
# Horizon:  4 MAE 26.97 SMAPE: 13.43 R2: 0.61

# CO+NO2 - Log+StandarScaler
# --------------------------------------------------
# Horizon:  1 MAE 11.25 SMAPE:  5.61 R2: 0.92
# Horizon:  2 MAE 17.95 SMAPE:  8.89 R2: 0.80
# Horizon:  3 MAE 22.76 SMAPE: 11.21 R2: 0.69
# Horizon:  4 MAE 27.30 SMAPE: 13.57 R2: 0.58


# All-data - Log+StandarScaler
# --------------------------------------------------
# Horizon:  1 MAE 11.43 SMAPE:  5.70 R2: 0.93
# Horizon:  2 MAE 18.19 SMAPE:  8.95 R2: 0.81
# Horizon:  3 MAE 23.12 SMAPE: 11.47 R2: 0.71
# Horizon:  4 MAE 27.07 SMAPE: 13.52 R2: 0.61

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]
    
            
    from scipy import stats
    from statsmodels.graphics.tsaplots import plot_acf
    
    res = (Prices[targetSeries] - Prices['Prediction']).to_numpy()
    
    fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

    ax[0].hist( res, bins = 100 )    
    plot_acf( res, ax=ax[1] )
# Out:
# [INFO] Feature:  CO
# ------------------------------------------------

# %% [markdown]
# ## Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]
RandomInstances = [913, 205, 2254, 2007, 1829, 1144, 840, 713, 3457]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    plt.grid()
#     plot_scatter(range(0, Lag),             testX[i,:Lag], color='b')
    plt.plot(range(Lag, Lag + Horizon), testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(range(Lag, Lag + Horizon), pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Instance', 'Future values', 'Prediction'], frameon = False, fontsize = 12)
plt.show()

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame( [] )


Outputs[ targetSeries ] = testY.flatten()
Outputs['Seq2Seq_LSTM'] = pred.flatten()

Outputs.to_csv('Predictions/Seq2Seq_LSTM.csv')
