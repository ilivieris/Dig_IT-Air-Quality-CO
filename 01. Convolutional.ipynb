# %% [markdown]
# # Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# import tensorflow as tf
# tf.config.experimental_run_functions_eagerly(True)
# tf.keras.backend.set_floatx('float64')

# import tensorflow.python.util.deprecation as deprecation
# deprecation._PRINT_DEPRECATION_WARNINGS = False

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import math
import time
import timeit
from   tqdm    import tqdm
import pandas  as pd
import numpy   as np


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot                        as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import *
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from utils.PerformanceMetrics import RegressionEvaluation


print('[INFO] Libraries imported')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [INFO] Libraries imported

# %% [markdown]
# # Parameters

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## CUDA

# %%
try:
    gpus = tensorflow.config.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)

            logical_gpus = tensorflow.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")

        except RuntimeError as e:

            # Memory growth must be set before GPUs have been initialized
            print(e)
except:
    print('[INFO] Not GPU found')

# %% [markdown]
# ## Training paramers

# %%
Lag        =   12
Horizon    =   4
#
epochs     =  200
batch_size =   32

Transformation = True

# %% [markdown]
# # Importing data

# %%
# Parameters
#
filename   = '../metadata/7-kanal-1.csv'

Transformation  = True
Scaling         = 'Standard'

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.39 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %% [markdown]
# ## Preprocess

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)



df = df.resample('5min').mean().interpolate()
# df = pd.DataFrame( df[ ['CO'] ] )
df = pd.DataFrame( df[ ['NO2', 'CO'] ] )
# df = pd.DataFrame( df[ ['Temperature', 'Humidity', 'NO2', 'CO'] ] )


df.head(3)
# Out:
#                             NO2          CO
# Date
# 2022-02-19 00:00:00  186.210526  248.947368
# 2022-02-19 00:05:00  151.052632  232.473684
# 2022-02-19 00:10:00  135.315789  226.947368

# %%
targetSeries = df.columns[-1]

# %% [markdown]
# ## Split Training/Testing set

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %%
print('Training: ', df_train.shape[0])
print('Testing:  ', df_test.shape[0])
# Out:
# Training:  17116
# Testing:   4280

# %% [markdown]
# ## Visualize Training & Testing data

# %%
plt.figure( figsize = (20, 4) );
#
df_train[ targetSeries ].plot()
df_test[ targetSeries ].plot()
#
plt.legend(['Training', 'Validation', 'Testing'], fontsize = 12);
plt.ylabel( targetSeries, size = 12);
plt.xlabel( 'Time', size = 12);

# %% [markdown]
# ## Fix lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Contruction of fitting data for training a forecasting model

# %% [markdown]
# ### Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = np.ceil( max(-df.min().min(), 1.0) )
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ### Data scaling

# %%
for feature in df_train.columns:
    if (feature == targetSeries): continue

    # Setup scaler
    #
    scaler = StandardScaler()

    # Performing Scaling - for each feature
    df_train[feature] = scaler.fit_transform( df_train[feature].to_numpy().reshape(-1,1) )
    df_test[feature]  = scaler.transform( df_test[feature].to_numpy().reshape(-1,1) )


# Setup scaler
#
scaler = StandardScaler()

df_train[targetSeries] = scaler.fit_transform( df_train[targetSeries].to_numpy().reshape(-1,1) )
df_test[targetSeries]  = scaler.transform( df_test[targetSeries].to_numpy().reshape(-1,1) )

# %% [markdown]
# ### Include date/time features

# %%
# df_train['Time (sin)'] = np.sin( df_train.index.hour + df_train.index.minute / 60 )
# df_train['Time (cos)'] = np.cos( df_train.index.hour + df_train.index.minute / 60 )
# #
# df_test['Time (sin)']  = np.sin( df_test.index.hour + df_test.index.minute / 60 )
# df_test['Time (cos)']  = np.cos( df_test.index.hour + df_test.index.minute / 60 )

# %% [markdown]
# ### Create fitting data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, overlap = 1):
    
    if (targetSeries is None):
        targetSeries = df.columns[-1]
    
    dataX, dataY = [], []
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):
        
        dataX.append( df.to_numpy()[i:(i+Lag)] )        
        dataY.append( df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon] )
        
        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df           = df_train, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = Horizon)
                               

testX,  testY  = create_dataset(df           = df_test, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = 1)


print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4276/4276 [00:00<00:00, 104494.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4277/4277 [00:00<00:00, 87562.60it/s]
# Training instances:     4276
# Testing instances:      4277

# %%
trainX.shape, trainY.shape
# Out:
# ((4276, 12, 2), (4276, 4))

# %% [markdown]
# # Forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsolutePercentageError(name = "MAPE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]
# Out:
# 2022-05-11 16:24:16.517028: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from utils.Attention import *
# https://github.com/philipperemy/keras-attention-mechanism


model_input = Input(shape=( trainX.shape[1], trainX.shape[2]) )   


x = Conv1D(filters=32, kernel_size=2, padding='same', activation='relu' )(model_input)
x = MaxPool1D(2)(x)
x = Conv1D(filters=64, kernel_size=2, padding='same', activation='relu' )(x)
x = Attention(100)(x)
#
x = Dense(32)(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)
  
x = Dense(Horizon, activation='linear')(x)


model = Model(model_input, x)

# %% [markdown]
# ## Training forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsoluteError(name = "MAE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]


model.compile(loss      = 'mse', 
              optimizer = Adam(learning_rate = 5.e-4), 
              metrics   = metrics)

# %%
# Checkpoint
#
checkpoint = ModelCheckpoint("models/Convolutional.hdf5", 
                              monitor        = 'val_loss', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 10)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_loss', 
                                   factor      = 0.5,
                                   patience    = 5)

# %%
# Start clock
#
start = timeit.default_timer()


score = model.fit(trainX, trainY, 
                  epochs          = epochs, 
                  batch_size      = batch_size, 
                  callbacks       = [checkpoint, earlystopping, lrs_scheduler],
                  verbose         = 1, 
                  shuffle         = True,
                  validation_data = (testX, testY))


# Terminate clock
#
stop = timeit.default_timer()
# Out:
# Epoch 1/200
# 134/134 [==============================] - 1s 5ms/step - loss: 0.6910 - MAE: 0.6172 - RMSE: 0.8313 - val_loss: 1.2693 - val_MAE: 0.9176 - val_RMSE: 1.1266 - lr: 5.0000e-04
# Epoch 2/200
# 134/134 [==============================] - 1s 4ms/step - loss: 0.5689 - MAE: 0.5614 - RMSE: 0.7543 - val_loss: 0.9821 - val_MAE: 0.7895 - val_RMSE: 0.9910 - lr: 5.0000e-04
# Epoch 3/200
# 134/134 [==============================] - 1s 5ms/step - loss: 0.4899 - MAE: 0.5245 - RMSE: 0.6999 - val_loss: 0.6643 - val_MAE: 0.6430 - val_RMSE: 0.8151 - lr: 5.0000e-04
# Epoch 4/200
# 134/134 [==============================] - 1s 5ms/step - loss: 0.4214 - MAE: 0.4854 - RMSE: 0.6491 - val_loss: 0.5199 - val_MAE: 0.5716 - val_RMSE: 0.7210 - lr: 5.0000e-04
# Epoch 5/200
# 134/134 [==============================] - 1s 4ms/step - loss: 0.3912 - MAE: 0.4689 - RMSE: 0.6255 - val_loss: 0.4370 - val_MAE: 0.5007 - val_RMSE: 0.6611 - lr: 5.0000e-04
# Epoch 6/200
# 134/134 [==============================] - 1s 4ms/step - loss: 0.3356 - MAE: 0.4361 - RMSE: 0.5794 - val_loss: 0.4630 - val_MAE: 0.5117 - val_RMSE: 0.6805 - lr: 5.0000e-04
# Epoch 7/200
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2804 - MAE: 0.3971 - RMSE: 0.5295 - val_loss: 0.5632 - val_MAE: 0.6219 - val_RMSE: 0.7505 - lr: 5.0000e-04
# Epoch 8/200
# 134/134 [==============================] - 1s 6ms/step - loss: 0.2594 - MAE: 0.3813 - RMSE: 0.5093 - val_loss: 0.3766 - val_MAE: 0.4599 - val_RMSE: 0.6137 - lr: 5.0000e-04
# Epoch 9/200
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2386 - MAE: 0.3642 - RMSE: 0.4885 - val_loss: 0.3483 - val_MAE: 0.4066 - val_RMSE: 0.5902 - lr: 5.0000e-04
# Epoch 10/200
# 134/134 [==============================] - 1s 4ms/step - loss: 0.2240 - MAE: 0.3481 - RMSE: 0.4733 - val_loss: 0.3345 - val_MAE: 0.4060 - val_RMSE: 0.5783 - lr: 5.0000e-04
# Epoch 11/200
# 134/134 [==============================] - 0s 3ms/step - loss: 0.2196 - MAE: 0.3443 - RMSE: 0.4686 - val_loss: 0.3949 - val_MAE: 0.4829 - val_RMSE: 0.6284 - lr: 5.0000e-04
# Epoch 12/200
# 134/134 [==============================] - 0s 4ms/step - loss: 0.
200
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1932 - MAE: 0.3186 - RMSE: 0.4395 - val_loss: 0.3236 - val_MAE: 0.3681 - val_RMSE: 0.5689 - lr: 6.2500e-05
# Epoch 33/200
# 134/134 [==============================] - 0s 4ms/step - loss: 0.1922 - MAE: 0.3213 - RMSE: 0.4384 - val_loss: 0.3062 - val_MAE: 0.3754 - val_RMSE: 0.5533 - lr: 6.2500e-05
# Epoch 34/200
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1878 - MAE: 0.3160 - RMSE: 0.4334 - val_loss: 0.3204 - val_MAE: 0.4008 - val_RMSE: 0.5660 - lr: 6.2500e-05
# Epoch 35/200
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1836 - MAE: 0.3111 - RMSE: 0.4285 - val_loss: 0.3122 - val_MAE: 0.3760 - val_RMSE: 0.5588 - lr: 6.2500e-05
# Epoch 36/200
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1918 - MAE: 0.3221 - RMSE: 0.4379 - val_loss: 0.3099 - val_MAE: 0.3805 - val_RMSE: 0.5567 - lr: 3.1250e-05
# Epoch 37/200
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1905 - MAE: 0.3187 - RMSE: 0.4365 - val_loss: 0.3102 - val_MAE: 0.3769 - val_RMSE: 0.5569 - lr: 3.1250e-05
# Epoch 38/200
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1854 - MAE: 0.3138 - RMSE: 0.4306 - val_loss: 0.3100 - val_MAE: 0.3717 - val_RMSE: 0.5568 - lr: 3.1250e-05
# Epoch 39/200
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1972 - MAE: 0.3263 - RMSE: 0.4441 - val_loss: 0.3083 - val_MAE: 0.3715 - val_RMSE: 0.5553 - lr: 3.1250e-05
# Epoch 40/200
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1848 - MAE: 0.3115 - RMSE: 0.4299 - val_loss: 0.3129 - val_MAE: 0.3701 - val_RMSE: 0.5593 - lr: 3.1250e-05
# Epoch 41/200
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1808 - MAE: 0.3086 - RMSE: 0.4252 - val_loss: 0.3115 - val_MAE: 0.3717 - val_RMSE: 0.5581 - lr: 1.5625e-05
# Epoch 42/200
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1821 - MAE: 0.3100 - RMSE: 0.4267 - val_loss: 0.3104 - val_MAE: 0.3737 - val_RMSE: 0.5571 - lr: 1.5625e-05
# Epoch 43/200
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1888 - MAE: 0.3203 - RMSE: 0.4345 - val_loss: 0.3153 - val_MAE: 0.3677 - val_RMSE: 0.5615 - lr: 1.5625e-05
# Epoch 00043: early stopping

# %%
# Create figure
#
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 3) )

# Plot RMSE
#
ax[0].plot( score.history['RMSE'], marker = 'o');
ax[0].plot( score.history['val_RMSE'], marker = 'o');
ax[0].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[0].set_title('RMSE');

# Plot RMSE
#
ax[1].plot( score.history['MAE'], marker = 'o');
ax[1].plot( score.history['val_MAE'], marker = 'o');
ax[1].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[1].set_title('MAE');

# %% [markdown]
# ## Load optimized forecasting model

# %%
# Load the best model
#
model.load_weights('models/Convolutional.hdf5')

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Get predictions

# %%
# Get predictions
#
pred = model.predict( testX )

# %% [markdown]
# ## Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred = np.exp( pred )   - VALUE

# %% [markdown]
# ## Visualization of predictions

# %%
Results = dict()

for i in range( Horizon ):
    Prices = pd.DataFrame( [] )

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]
    

        
    # Store results
    #
    Results[ 'Horizon {}'.format(i+1) ] = Prices

    
    
    
    # Plot results
    #
    plt.figure( figsize = (20, 4) );
    #
    Prices[ targetSeries ][:100].plot(color = 'tab:blue', marker = 'o')
    Prices[ 'Prediction' ][:100].plot(color = 'tab:orange', marker = 'o')
    
    #
    #
    plt.legend([targetSeries, 'Prediction'], fontsize = 12, frameon=False);
    plt.ylabel(targetSeries, size = 12 );
    plt.xlabel('Time', size = 12);
    plt.show()

# %% [markdown]
# ## Regression evaluation

# %%
sResults = {'MAE': [], 'RMSE': [], 'MAPE': [], 'SMAPE': [], 'R2': []}

for i in range(Horizon):
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Results['Horizon {}'.format(i+1)] )
    
    sResults['MAE']   += [MAE]
    sResults['RMSE']  += [RMSE]
    sResults['MAPE']  += [MAPE]
    sResults['SMAPE'] += [SMAPE]
    sResults['R2']    += [R2]
    
    
#     print('Horizon -%i-' % (i+1))
#     print('--------------')
#     print('MAE   = %.3f' % MAE)
#     print('RMSE  = %.3f' % RMSE)
#     print('MAPE  = %.3f' % MAPE)
#     print('SMAPE = %.3f' % SMAPE)
#     print('R2    = %.3f' % R2)
#     print()
    print('Horizon: %2i MAE %5.2f SMAPE: %5.2f R2: %.2f' %(i+1, MAE, SMAPE, R2) )
# Out:
# Horizon:  1 MAE 10.12 SMAPE:  4.92 R2: 0.94
# Horizon:  2 MAE 17.72 SMAPE:  8.71 R2: 0.82
# Horizon:  3 MAE 22.95 SMAPE: 11.42 R2: 0.72
# Horizon:  4 MAE 26.88 SMAPE: 13.43 R2: 0.62

# %%
# CO+NO2 - Log+StandarScaler
# --------------------------------------------------
# Horizon:  1 MAE 10.12 SMAPE:  4.92 R2: 0.94
# Horizon:  2 MAE 17.72 SMAPE:  8.71 R2: 0.82
# Horizon:  3 MAE 22.95 SMAPE: 11.42 R2: 0.72
# Horizon:  4 MAE 26.88 SMAPE: 13.43 R2: 0.62

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]
    
            
    from scipy import stats
    from statsmodels.graphics.tsaplots import plot_acf
    
    res = (Prices[targetSeries] - Prices['Prediction']).to_numpy()
    
    fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

    ax[0].hist( res, bins = 100 )    
    plot_acf( res, ax=ax[1] )
# Out:
# [INFO] Feature:  CO
# ------------------------------------------------

# %% [markdown]
# ## Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]
RandomInstances = [913, 205, 2254, 2007, 1829, 1144, 840, 713, 3457]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    plt.grid()
#     plot_scatter(range(0, Lag),             testX[i,:Lag], color='b')
    plt.plot(range(Lag, Lag + Horizon), testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(range(Lag, Lag + Horizon), pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Instance', 'Future values', 'Prediction'], frameon = False, fontsize = 12)
plt.show()

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame( [] )


Outputs[ targetSeries ] = testY.flatten()
Outputs['Convolutional'] = pred.flatten()

Outputs.to_csv('Predictions/Convolutional.csv')
