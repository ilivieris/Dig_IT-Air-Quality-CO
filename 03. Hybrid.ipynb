# %% [markdown]
# # Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# import tensorflow as tf
# tf.config.experimental_run_functions_eagerly(True)
# tf.keras.backend.set_floatx('float64')

# import tensorflow.python.util.deprecation as deprecation
# deprecation._PRINT_DEPRECATION_WARNINGS = False

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import math
import time
import timeit
from   tqdm    import tqdm
import pandas  as pd
import numpy   as np


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot                        as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import EarlyStopping
from   tensorflow.keras.callbacks               import ModelCheckpoint
from   tensorflow.keras.callbacks               import ReduceLROnPlateau
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from utils.PerformanceMetrics import RegressionEvaluation


print('[INFO] Libraries imported')
# Out:
# [INFO] Libraries imported

# %% [markdown]
# # Parameters

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## CUDA

# %%
try:
    gpus = tensorflow.config.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)

            logical_gpus = tensorflow.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")

        except RuntimeError as e:

            # Memory growth must be set before GPUs have been initialized
            print(e)
except:
    print('[INFO] Not GPU found')

# %% [markdown]
# ## Training paramers

# %%
Lag        =   12
Horizon    =    4
#
epochs     =  200
batch_size =   32

Transformation = True

# %% [markdown]
# # Importing data

# %%
# Parameters
#
filename   = '../metadata/7-kanal-1.csv'

Transformation  = True
Scaling         = 'Standard'

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.44 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %% [markdown]
# ## Preprocess

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)


df = df.resample('5min').mean().interpolate()
# df = pd.DataFrame( df[['Temperature', 'Humidity', 'NO2', 'CO']] )
df = pd.DataFrame( df[['NO2', 'CO']] )
# df = pd.DataFrame( df[ 'CO' ] )


df.head(3)
# Out:
#                             NO2          CO
# Date
# 2022-02-19 00:00:00  186.210526  248.947368
# 2022-02-19 00:05:00  151.052632  232.473684
# 2022-02-19 00:10:00  135.315789  226.947368

# %%
targetSeries = df.columns[-1]

# %% [markdown]
# ## Include MA-based features

# %%
# df['MA6']  = df[ targetSeries ].rolling(6).mean()
# df['MA12'] = df[ targetSeries ].rolling(12).mean()
#
# df['MA5'] = df[ targetSeries ].rolling(5).mean()
# df['MA9'] = df[ targetSeries ].rolling(9).mean()

# %% [markdown]
# ## Split Training/Testing set

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %%
print('Training: ', df_train.shape[0])
print('Testing:  ', df_test.shape[0])
# Out:
# Training:  17116
# Testing:   4280

# %% [markdown]
# ## Visualize Training & Testing data

# %%
plt.figure( figsize = (20, 4) );
#
df_train[ targetSeries ].plot()
df_test[ targetSeries ].plot()
#
plt.legend(['Training', 'Validation', 'Testing'], fontsize = 12);
plt.ylabel( targetSeries, size = 12);
plt.xlabel( 'Time', size = 12);

# %% [markdown]
# ## Fix lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Contruction of fitting data for training a forecasting model

# %% [markdown]
# ### Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = np.ceil( max(-df.min().min(), 1.0) )
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ### Data scaling

# %%
for feature in df_train.columns:
    if (feature == targetSeries): continue

    # Setup scaler
    #
    scaler = StandardScaler()

    # Performing Scaling - for each feature
    df_train[feature] = scaler.fit_transform( df_train[feature].to_numpy().reshape(-1,1) )
    df_test[feature]  = scaler.transform( df_test[feature].to_numpy().reshape(-1,1) )


# Setup scaler
#
scaler = StandardScaler()

df_train[targetSeries] = scaler.fit_transform( df_train[targetSeries].to_numpy().reshape(-1,1) )
df_test[targetSeries]  = scaler.transform( df_test[targetSeries].to_numpy().reshape(-1,1) )

# %% [markdown]
# ### Create fitting data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, includeLagData = False, includeDate = False, overlap = 1):
    
    if (targetSeries is None):
        targetSeries = df.columns[-1]
    
    dataX, dataY = [], []
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):
        
        # Original data
        data       = df.to_numpy()[i+1:(i+Lag)]        
        
        # Include date info
        if (includeDate):            
            myDate = [ np.sin(df[i+1:(i+Lag)].index.hour + df[i+1:(i+Lag)].index.minute / 60 ).tolist(), 
                       np.cos(df[i+1:(i+Lag)].index.hour + df[i+1:(i+Lag)].index.minute / 60 ).tolist() ]
            myDate = np.asarray( myDate ).T
            #
            # Concatenate data            
            data = np.concatenate([data, myDate], axis = -1)

        # data_diff: Lag-d differences
        if (includeLagData):
            data_diff  = (df.iloc[i+Lag-1] - df.iloc[i:(i+Lag-1)]).to_numpy()
            #
            # Concatenate data
            data = np.concatenate([data, data_diff], axis = -1)
                
        
        # Concatenate data
        dataX.append( data )
        
        # Targets 
        dataY.append( df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon] )
        
        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df             = df_train, 
                                Lag            = Lag, 
                                Horizon        = Horizon, 
                                targetSeries   = targetSeries,
                                includeLagData = True,
                                includeDate    = False,
                                overlap        = Horizon)
                               

testX,  testY  = create_dataset(df             = df_test, 
                                Lag            = Lag, 
                                Horizon        = Horizon, 
                                targetSeries   = targetSeries,
                                includeLagData = True,
                                includeDate    = False,
                                overlap        = 1)


print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0] )
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4276/4276 [00:02<00:00, 1529.49it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4277/4277 [00:03<00:00, 1381.42it/s]
# Training instances:     4276
# Testing instances:      4277

# %%
trainX.shape, trainY.shape
# Out:
# ((4276, 11, 4), (4276, 4))

# %% [markdown]
# # Forecasting model

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## Setup model

# %%
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.models                  import *

# Inputs
#
Inputs = Input(shape = (trainX.shape[1], trainX.shape[2]))


# Encoder
#
Encoder = LSTM(units = 100, activation='relu')( Inputs )

# Decoder
#
Decoder = RepeatVector( Horizon )(Encoder)
#
Decoder = LSTM(units = 100, activation='relu')( Decoder )
#
# Output
#
Outputs = Dense( Horizon, activation='linear' )( Decoder )


# Create model
#
model = Model(inputs = Inputs, outputs = Outputs)
# Out:
# 2022-05-11 14:35:53.657420: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Training forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsoluteError(name = "MAE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]


model.compile(loss      = 'mse', 
              optimizer = Adam(learning_rate = 5.e-4), 
              metrics   = metrics)

# %%
# Checkpoint
#
checkpoint = ModelCheckpoint("models/Hybrid.hdf5", 
                              monitor        = 'val_loss', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 40)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_loss', 
                                   factor      = 0.5,
                                   patience    = 20)

# %%
# Start clock
#
start = timeit.default_timer()


score = model.fit(trainX, trainY, 
                  epochs          = epochs, 
                  batch_size      = batch_size, 
                  callbacks       = [checkpoint, earlystopping, lrs_scheduler],
                  verbose         = True, 
                  shuffle         = True,
                  validation_data = (testX, testY))


# Terminate clock
#
stop = timeit.default_timer()
# Out:
# Epoch 1/200
# 134/134 [==============================] - 5s 18ms/step - loss: 0.4131 - MAE: 0.4640 - RMSE: 0.6427 - val_loss: 1.0212 - val_MAE: 0.6188 - val_RMSE: 1.0105 - lr: 5.0000e-04
# Epoch 2/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1814 - MAE: 0.2956 - RMSE: 0.4259 - val_loss: 0.5598 - val_MAE: 0.4898 - val_RMSE: 0.7482 - lr: 5.0000e-04
# Epoch 3/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1736 - MAE: 0.2820 - RMSE: 0.4166 - val_loss: 0.3965 - val_MAE: 0.4269 - val_RMSE: 0.6297 - lr: 5.0000e-04
# Epoch 4/200
# 134/134 [==============================] - 2s 17ms/step - loss: 0.1704 - MAE: 0.2788 - RMSE: 0.4128 - val_loss: 0.3620 - val_MAE: 0.3945 - val_RMSE: 0.6017 - lr: 5.0000e-04
# Epoch 5/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1701 - MAE: 0.2772 - RMSE: 0.4124 - val_loss: 0.3634 - val_MAE: 0.3988 - val_RMSE: 0.6028 - lr: 5.0000e-04
# Epoch 6/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1689 - MAE: 0.2747 - RMSE: 0.4110 - val_loss: 0.3603 - val_MAE: 0.3932 - val_RMSE: 0.6002 - lr: 5.0000e-04
# Epoch 7/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1670 - MAE: 0.2733 - RMSE: 0.4086 - val_loss: 0.3241 - val_MAE: 0.3819 - val_RMSE: 0.5693 - lr: 5.0000e-04
# Epoch 8/200
# 134/134 [==============================] - 2s 17ms/step - loss: 0.1661 - MAE: 0.2726 - RMSE: 0.4076 - val_loss: 0.3203 - val_MAE: 0.3776 - val_RMSE: 0.5660 - lr: 5.0000e-04
# Epoch 9/200
# 134/134 [==============================] - 2s 17ms/step - loss: 0.1659 - MAE: 0.2732 - RMSE: 0.4074 - val_loss: 0.3475 - val_MAE: 0.3824 - val_RMSE: 0.5895 - lr: 5.0000e-04
# Epoch 10/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1638 - MAE: 0.2697 - RMSE: 0.4047 - val_loss: 0.3354 - val_MAE: 0.3834 - val_RMSE: 0.5792 - lr: 5.0000e-04
# Epoch 11/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1646 - MAE: 0.2706 - RMSE: 0.4057 - val_loss: 0.3235 - val_MAE: 0.3761 - val_RMSE: 0.5688 - lr: 5.0000e-04
# Epoch 12/200
# 134/134 [==============================] - 2s 18ms/step - loss: 0.1637 - MAE: 0.2715 - RMSE: 0.4045 - val_loss: 0.3626 - val_MAE: 0.3981 - val_RMSE: 0.6021 - lr: 5.0000e-04
# Epoch 13/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1641 - MAE: 0.2719 - RMSE: 0.4050 - val_loss: 0.3433 - val_MAE: 0.3814 - val_RMSE: 0.5859 - lr: 5.0000e-04
# Epoch 14/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1629 - MAE: 0.2699 - RMSE: 0.4037 - val_loss: 0.3234 - val_MAE: 0.3680 - val_RMSE: 0.5686 - lr: 5.0000e-04
# Epoch 15/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1610 - MAE: 0.2679 - RMSE: 0.4013 - val_loss: 0.3256 - val_MAE: 0.3765 - val_RMSE: 0.5706 - lr: 5.0000e-04
# Epoch 16/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1613 - MAE: 0.2704 - RMSE: 0.4016 - val_loss: 0.3233 - val_MAE: 0.3703 - val_RMSE: 0.5686 - lr: 5.0000e-04
# Epoch 17/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1597 - MAE: 0.2653 - RMSE: 0.3996 - val_loss: 0.3185 - val_MAE: 0.3683 - val_RMSE: 0.5643 - lr: 5.0000e-04
# Epoch 18/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1587 - MAE: 0.2654 - RMSE: 0.3984 - val_loss: 0.3170 - val_MAE: 0.3655 - val_RMSE: 0.5630 - lr: 5.0000e-04
# Epoch 19/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1587 - MAE: 0.2659 - RMSE: 0.3984 - val_loss: 0.3134 - val_MAE: 0.3705 - val_RMSE: 0.5598 - lr: 5.0000e-04
# Epoch 20/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.1589 - MAE: 0.2669 - RMSE: 0.3987 - val_loss: 0.3093 - val_MAE: 0.3630 - val_RMSE: 0.5562 - lr: 5.0000e-04
# Epoch 21/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1600 - MAE: 0.2684 - RMSE: 0.4000 - val_loss: 0.3135 - val_MAE: 0.3783 - val_RMSE: 0.5599 - lr: 5.0000e-04
# Epoch 22/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1583 - MAE: 0.2661 - RMSE: 0.3978 - val_loss: 0.3248 - val_MAE: 0.3679 - val_RMSE: 0.5699 - lr: 5.0000e-04
# Epoch 23/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1575 - MAE: 0.2650 - RMSE: 0.3969 - val_loss: 0.3298 - val_MAE: 0.4233 - val_RMSE: 0.5743 - lr: 5.0000e-04
# Epoch 24/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1575 - MAE: 0.2655 - RMSE: 0.3968 - val_loss: 0.3301 - val_MAE: 0.3690 - val_RMSE: 0.5745 - lr: 5.0000e-04
# Epoch 25/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1555 - MAE: 0.2629 - RMSE: 0.3943 - val_loss: 0.3106 - val_MAE: 0.3736 - val_RMSE: 0.5574 - lr: 5.0000e-04
# Epoch 26/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1574 - MAE: 0.2658 - RMSE: 0.3967 - val_loss: 0.3421 - val_MAE: 0.3801 - val_RMSE: 0.5849 - lr: 5.0000e-04
# Epoch 27/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1568 - MAE: 0.2659 - RMSE: 0.3959 - val_loss: 0.3384 - val_MAE: 0.3834 - val_RMSE: 0.5817 - lr: 5.0000e-04
# Epoch 28/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1554 - MAE: 0.2642 - RMSE: 0.3942 - val_loss: 0.3180 - val_MAE: 0.3599 - val_RMSE: 0.5639 - lr: 5.0000e-04
# Epoch 29/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1544 - MAE: 0.2628 - RMSE: 0.3930 - val_loss: 0.3197 - val_MAE: 0.3904 - val_RMSE: 0.5655 - lr: 5.0000e-04
# Epoch 30/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1552 - MAE: 0.2645 - RMSE: 0.3939 - val_loss: 0.3152 - val_MAE: 0.3773 - val_RMSE: 0.5615 - lr: 5.0000e-04
# Epoch 31/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1570 - MAE: 0.2667 - RMSE: 0.3962 - val_loss: 0.3317 - val_MAE: 0.3678 - val_RMSE: 0.5759 - lr: 5.0000e-04
# Epoch 32/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1527 - MAE: 0.2589 - RMSE: 0.3908 - val_loss: 0.3660 - val_MAE: 0.3857 - val_RMSE: 0.6050 - lr: 5.0000e-04
# Epoch 33/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1527 - MAE: 0.2616 - RMSE: 0.3908 - val_loss: 0.3130 - val_MAE: 0.3664 - val_RMSE: 0.5594 - lr: 5.0000e-04
# Epoch 34/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1523 - MAE: 0.2597 - RMSE: 0.3902 - val_loss: 0.3147 - val_MAE: 0.3962 - val_RMSE: 0.5610 - lr: 5.0000e-04
# Epoch 35/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1518 - MAE: 0.2604 - RMSE: 0.3896 - val_loss: 0.3106 - val_MAE: 0.3672 - val_RMSE: 0.5573 - lr: 5.0000e-04
# Epoch 36/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1514 - MAE: 0.2597 - RMSE: 0.3891 - val_loss: 0.3067 - val_MAE: 0.3709 - val_RMSE: 0.5538 - lr: 5.0000e-04
# Epoch 37/200
# 134/134 [==============================] - 1s 7ms/step - loss: 0.1523 - MAE: 0.2620 - RMSE: 0.3902 - val_loss: 0.3195 - val_MAE: 0.3753 - val_RMSE: 0.5653 - lr: 5.0000e-04
# Epoch 38/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1506 - MAE: 0.2597 - RMSE: 0.3881 - val_loss: 0.3149 - val_MAE: 0.3898 - val_RMSE: 0.5612 - lr: 5.0000e-04
# Epoch 39/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1499 - MAE: 0.2585 - RMSE: 0.3872 - val_loss: 0.3194 - val_MAE: 0.3892 - val_RMSE: 0.5651 - lr: 5.0000e-04
# Epoch 40/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1494 - MAE: 0.2584 - RMSE: 0.3866 - val_loss: 0.3903 - val_MAE: 0.4019 - val_RMSE: 0.6247 - lr: 5.0000e-04
# Epoch 41/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1490 - MAE: 0.2574 - RMSE: 0.3861 - val_loss: 0.3176 - val_MAE: 0.3923 - val_RMSE: 0.5636 - lr: 5.0000e-04
# Epoch 42/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1501 - MAE: 0.2598 - RMSE: 0.3874 - val_loss: 0.3252 - val_MAE: 0.3713 - val_RMSE: 0.5702 - lr: 5.0000e-04
# Epoch 43/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1485 - MAE: 0.2570 - RMSE: 0.3853 - val_loss: 0.3099 - val_MAE: 0.3674 - val_RMSE: 0.5567 - lr: 5.0000e-04
# Epoch 44/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1475 - MAE: 0.2567 - RMSE: 0.3840 - val_loss: 0.3352 - val_MAE: 0.3706 - val_RMSE: 0.5789 - lr: 5.0000e-04
# Epoch 45/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1490 - MAE: 0.2592 - RMSE: 0.3861 - val_loss: 0.3197 - val_MAE: 0.3720 - val_RMSE: 0.5654 - lr: 5.0000e-04
# Epoch 46/200
# 134/134 [==============================] - 1s 7ms/step - loss: 0.1475 - MAE: 0.2574 - RMSE: 0.3841 - val_loss: 0.3348 - val_MAE: 0.3690 - val_RMSE: 0.5786 - lr: 5.0000e-04
# Epoch 47/200
# 134/134 [==============================] - 1s 7ms/step - loss: 0.1476 - MAE: 0.2571 - RMSE: 0.3841 - val_loss: 0.3446 - val_MAE: 0.3773 - val_RMSE: 0.5870 - lr: 5.0000e-04
# Epoch 48/200
# 134/134 [==============================] - 1s 7ms/step - loss: 0.1467 - MAE: 0.2555 - RMSE: 0.3830 - val_loss: 0.3198 - val_MAE: 0.3959 - val_RMSE: 0.5655 - lr: 5.0000e-04
# Epoch 49/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1464 - MAE: 0.2565 - RMSE: 0.3826 - val_loss: 0.3235 - val_MAE: 0.3636 - val_RMSE: 0.5688 - lr: 5.0000e-04
# Epoch 50/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1458 - MAE: 0.2559 - RMSE: 0.3818 - val_loss: 0.3282 - val_MAE: 0.3896 - val_RMSE: 0.5729 - lr: 5.0000e-04
# Epoch 51/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1455 - MAE: 0.2553 - RMSE: 0.3814 - val_loss: 0.3504 - val_MAE: 0.3902 - val_RMSE: 0.5919 - lr: 5.0000e-04
# Epoch 52/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1455 - MAE: 0.2558 - RMSE: 0.3815 - val_loss: 0.3486 - val_MAE: 0.3814 - val_RMSE: 0.5904 - lr: 5.0000e-04
# Epoch 53/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1446 - MAE: 0.2545 - RMSE: 0.3802 - val_loss: 0.3387 - val_MAE: 0.3838 - val_RMSE: 0.5820 - lr: 5.0000e-04
# Epoch 54/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1443 - MAE: 0.2553 - RMSE: 0.3799 - val_loss: 0.3521 - val_MAE: 0.3884 - val_RMSE: 0.5933 - lr: 5.0000e-04
# Epoch 55/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1443 - MAE: 0.2543 - RMSE: 0.3799 - val_loss: 0.4211 - val_MAE: 0.3947 - val_RMSE: 0.6489 - lr: 5.0000e-04
# Epoch 56/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1459 - MAE: 0.2566 - RMSE: 0.3819 - val_loss: 0.3423 - val_MAE: 0.3848 - val_RMSE: 0.5851 - lr: 5.0000e-04
# Epoch 57/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1406 - MAE: 0.2496 - RMSE: 0.3749 - val_loss: 0.3529 - val_MAE: 0.3947 - val_RMSE: 0.5940 - lr: 2.5000e-04
# Epoch 58/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1399 - MAE: 0.2502 - RMSE: 0.3740 - val_loss: 0.3538 - val_MAE: 0.3801 - val_RMSE: 0.5948 - lr: 2.5000e-04
# Epoch 59/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1391 - MAE: 0.2486 - RMSE: 0.3730 - val_loss: 0.3429 - val_MAE: 0.3972 - val_RMSE: 0.5855 - lr: 2.5000e-04
# Epoch 60/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1388 - MAE: 0.2487 - RMSE: 0.3725 - val_loss: 0.3397 - val_MAE: 0.3743 - val_RMSE: 0.5828 - lr: 2.5000e-04
# Epoch 61/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1376 - MAE: 0.2476 - RMSE: 0.3710 - val_loss: 0.3632 - val_MAE: 0.3835 - val_RMSE: 0.6027 - lr: 2.5000e-04
# Epoch 62/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1387 - MAE: 0.2489 - RMSE: 0.3724 - val_loss: 0.3555 - val_MAE: 0.3946 - val_RMSE: 0.5962 - lr: 2.5000e-04
# Epoch 63/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.1372 - MAE: 0.2471 - RMSE: 0.3704 - val_loss: 0.3781 - val_MAE: 0.3908 - val_RMSE: 0.6149 - lr: 2.5000e-04
# Epoch 64/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1371 - MAE: 0.2471 - RMSE: 0.3702 - val_loss: 0.3678 - val_MAE: 0.3832 - val_RMSE: 0.6065 - lr: 2.5000e-04
# Epoch 65/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1371 - MAE: 0.2479 - RMSE: 0.3703 - val_loss: 0.3872 - val_MAE: 0.3846 - val_RMSE: 0.6223 - lr: 2.5000e-04
# Epoch 66/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1377 - MAE: 0.2472 - RMSE: 0.3711 - val_loss: 0.3559 - val_MAE: 0.4092 - val_RMSE: 0.5966 - lr: 2.5000e-04
# Epoch 67/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1362 - MAE: 0.2467 - RMSE: 0.3690 - val_loss: 0.3898 - val_MAE: 0.3882 - val_RMSE: 0.6243 - lr: 2.5000e-04
# Epoch 68/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1366 - MAE: 0.2475 - RMSE: 0.3696 - val_loss: 0.4136 - val_MAE: 0.4082 - val_RMSE: 0.6431 - lr: 2.5000e-04
# Epoch 69/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1356 - MAE: 0.2458 - RMSE: 0.3682 - val_loss: 0.3582 - val_MAE: 0.3841 - val_RMSE: 0.5985 - lr: 2.5000e-04
# Epoch 70/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1347 - MAE: 0.2454 - RMSE: 0.3670 - val_loss: 0.3866 - val_MAE: 0.3858 - val_RMSE: 0.6218 - lr: 2.5000e-04
# Epoch 71/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1347 - MAE: 0.2456 - RMSE: 0.3670 - val_loss: 0.3520 - val_MAE: 0.3868 - val_RMSE: 0.5933 - lr: 2.5000e-04
# Epoch 72/200
# 134/134 [==============================] - 1s 7ms/step - loss: 0.1341 - MAE: 0.2441 - RMSE: 0.3662 - val_loss: 0.3482 - val_MAE: 0.4002 - val_RMSE: 0.5901 - lr: 2.5000e-04
# Epoch 73/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1332 - MAE: 0.2443 - RMSE: 0.3649 - val_loss: 0.4136 - val_MAE: 0.3922 - val_RMSE: 0.6431 - lr: 2.5000e-04
# Epoch 74/200
# 134/134 [==============================] - 1s 7ms/step - loss: 0.1330 - MAE: 0.2429 - RMSE: 0.3647 - val_loss: 0.3666 - val_MAE: 0.4003 - val_RMSE: 0.6055 - lr: 2.5000e-04
# Epoch 75/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1339 - MAE: 0.2454 - RMSE: 0.3659 - val_loss: 0.3398 - val_MAE: 0.3980 - val_RMSE: 0.5829 - lr: 2.5000e-04
# Epoch 76/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1335 - MAE: 0.2451 - RMSE: 0.3654 - val_loss: 0.3810 - val_MAE: 0.3838 - val_RMSE: 0.6173 - lr: 2.5000e-04
# Epoch 00076: early stopping

# %%
# Create figure
#
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 3) )

# Plot RMSE
#
ax[0].plot( score.history['RMSE'], marker = 'o');
ax[0].plot( score.history['val_RMSE'], marker = 'o');
ax[0].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[0].set_title('RMSE');

# Plot RMSE
#
ax[1].plot( score.history['MAE'], marker = 'o');
ax[1].plot( score.history['val_MAE'], marker = 'o');
ax[1].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[1].set_title('MAE');

# %% [markdown]
# ## Load optimized forecasting model

# %%
# Load the best model
#
model.load_weights('models/Hybrid.hdf5')

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Get predictions

# %%
# Get predictions
#
pred = model.predict( testX )

# %% [markdown]
# ## Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred = np.exp( pred )   - VALUE

# %% [markdown]
# ## Visualization of predictions

# %%
Results = dict()

for i in range( Horizon ):
    Prices = pd.DataFrame( [] )

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]
    

        
    # Store results
    #
    Results[ 'Horizon {}'.format(i+1) ] = Prices

    
    
    
    # Plot results
    #
    plt.figure( figsize = (20, 4) );
    #
    Prices[ targetSeries ][:100].plot(color = 'tab:blue',   marker = 'o')
    Prices[ 'Prediction' ][:100].plot(color = 'tab:orange', marker = 'o')
    
    #
    #
    plt.legend([targetSeries, 'Prediction'], fontsize = 12, frameon=False);
    plt.ylabel(targetSeries, size = 12 );
    plt.xlabel('Time', size = 12);
    plt.show()

# %% [markdown]
# ## Regression evaluation

# %%
sResults = {'MAE': [], 'RMSE': [], 'MAPE': [], 'SMAPE': [], 'R2': []}

for i in range(Horizon):
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Results['Horizon {}'.format(i+1)] )
    
    sResults['MAE']   += [MAE]
    sResults['RMSE']  += [RMSE]
    sResults['MAPE']  += [MAPE]
    sResults['SMAPE'] += [SMAPE]
    sResults['R2']    += [R2]
    
    
#     print('Horizon -%i-' % (i+1))
#     print('--------------')
#     print('MAE   = %.3f' % MAE)
#     print('RMSE  = %.3f' % RMSE)
#     print('MAPE  = %.3f' % MAPE)
#     print('SMAPE = %.3f' % SMAPE)
#     print('R2    = %.3f' % R2)
#     print()
    print('Horizon: %2i MAE %5.2f SMAPE: %5.2f R2: %.2f' %(i+1, MAE, SMAPE, R2) )
# Out:
# Horizon:  1 MAE  9.75 SMAPE:  4.79 R2: 0.94
# Horizon:  2 MAE 17.31 SMAPE:  8.49 R2: 0.82
# Horizon:  3 MAE 22.72 SMAPE: 11.31 R2: 0.72
# Horizon:  4 MAE 26.91 SMAPE: 13.42 R2: 0.62

# %%
# NBeats + d-Lag
# Horizon:  1 MAE  9.76 SMAPE:  4.72 R2: 0.94
# Horizon:  2 MAE 17.16 SMAPE:  8.30 R2: 0.81
# Horizon:  3 MAE 22.07 SMAPE: 10.72 R2: 0.69
# Horizon:  4 MAE 26.25 SMAPE: 12.78 R2: 0.58

# CO (d-Lag+Value) - Log+StandardScaler
# ------------------------------------------------
# Horizon:  1 MAE  9.88 SMAPE:  4.86 R2: 0.94
# Horizon:  2 MAE 17.18 SMAPE:  8.37 R2: 0.81
# Horizon:  3 MAE 22.26 SMAPE: 10.95 R2: 0.71
# Horizon:  4 MAE 26.50 SMAPE: 13.15 R2: 0.62


# CO + NO2 (d-Lag+Value) - Log+StandardScaler
# ------------------------------------------------
# Horizon:  1 MAE  9.75 SMAPE:  4.79 R2: 0.94
# Horizon:  2 MAE 17.31 SMAPE:  8.49 R2: 0.82
# Horizon:  3 MAE 22.72 SMAPE: 11.31 R2: 0.72
# Horizon:  4 MAE 26.91 SMAPE: 13.42 R2: 0.62


# CO + NO2 + Time (d-Lag+Value) - Log+StandardScaler
# ------------------------------------------------
# Horizon:  1 MAE  9.86 SMAPE:  4.84 R2: 0.94
# Horizon:  2 MAE 17.41 SMAPE:  8.60 R2: 0.83
# Horizon:  3 MAE 22.58 SMAPE: 11.30 R2: 0.72
# Horizon:  4 MAE 26.43 SMAPE: 13.19 R2: 0.63

# %%
# print('[INFO] Feature: ', targetSeries)
# print('------------------------------------------------')
# Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

# for i in range( Horizon ):

#     Prices[targetSeries] = testY[:,i]
#     Prices['Prediction'] = pred[:,i]
    
            
#     from scipy import stats
#     from statsmodels.graphics.tsaplots import plot_acf
    
#     res = (Prices[targetSeries] - Prices['Prediction']).to_numpy()
    
#     fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

#     ax[0].hist( res, bins = 100 )    
#     plot_acf( res, ax=ax[1] )

# %% [markdown]
# ## Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )  
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]
RandomInstances = [913, 205, 2254, 2007, 1829, 1144, 840, 713, 3457]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    #
    plt.plot(range(Lag, Lag + Horizon), testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(range(Lag, Lag + Horizon), pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Instance', 'Future values', 'Prediction'], frameon = False, fontsize = 12)
plt.show()

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame( [] )


Outputs[ targetSeries ] = testY.flatten()
Outputs['Hybrid']       = pred.flatten()

Outputs.to_csv('Predictions/Hybrid.csv')
