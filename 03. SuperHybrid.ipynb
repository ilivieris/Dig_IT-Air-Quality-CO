# %% [markdown]
# # Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# import tensorflow as tf
# tf.config.experimental_run_functions_eagerly(True)
# tf.keras.backend.set_floatx('float64')

# import tensorflow.python.util.deprecation as deprecation
# deprecation._PRINT_DEPRECATION_WARNINGS = False

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import math
import time
import timeit
from   tqdm    import tqdm
import pandas  as pd
import numpy   as np


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot                        as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import EarlyStopping
from   tensorflow.keras.callbacks               import ModelCheckpoint
from   tensorflow.keras.callbacks               import ReduceLROnPlateau
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from utils.PerformanceMetrics import RegressionEvaluation


print('[INFO] Libraries imported')
# Out:
# [INFO] Libraries imported

# %% [markdown]
# # Parameters

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## CUDA

# %%
try:
    gpus = tensorflow.config.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)

            logical_gpus = tensorflow.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")

        except RuntimeError as e:

            # Memory growth must be set before GPUs have been initialized
            print(e)
except:
    print('[INFO] Not GPU found')

# %% [markdown]
# ## Training paramers

# %%
Lag        =   12
Horizon    =    4
#
epochs     =  100
batch_size =   32

Transformation = True

# %% [markdown]
# # Importing data

# %%
# Parameters
#
filename   = '../metadata/7-kanal-1.csv'

Transformation  = True
Scaling         = 'Standard'

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.42 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %% [markdown]
# ## Preprocess

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)


df = df.resample('5min').mean().interpolate()
# df = pd.DataFrame( df[['Temperature', 'Humidity', 'NO2', 'CO']] )
df = pd.DataFrame( df[['NO2', 'CO']] )
# df = pd.DataFrame( df[ 'CO' ] )


df.head(3)
# Out:
#                             NO2          CO
# Date
# 2022-02-19 00:00:00  186.210526  248.947368
# 2022-02-19 00:05:00  151.052632  232.473684
# 2022-02-19 00:10:00  135.315789  226.947368

# %%
targetSeries = df.columns[-1]

# %% [markdown]
# ## Include MA-based features

# %%
# df['MA6']  = df[ targetSeries ].rolling(6).mean()
# df['MA12'] = df[ targetSeries ].rolling(12).mean()
#
# df['MA5'] = df[ targetSeries ].rolling(5).mean()
# df['MA9'] = df[ targetSeries ].rolling(9).mean()

# %% [markdown]
# ## Split Training/Testing set

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %%
print('Training: ', df_train.shape[0])
print('Testing:  ', df_test.shape[0])
# Out:
# Training:  17116
# Testing:   4280

# %% [markdown]
# ## Visualize Training & Testing data

# %%
plt.figure( figsize = (20, 4) );
#
df_train[ targetSeries ].plot()
df_test[ targetSeries ].plot()
#
plt.legend(['Training', 'Validation', 'Testing'], fontsize = 12);
plt.ylabel( targetSeries, size = 12);
plt.xlabel( 'Time', size = 12);

# %% [markdown]
# ## Fix lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Contruction of fitting data for training a forecasting model

# %% [markdown]
# ### Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = np.ceil( max(-df.min().min(), 1.0) )
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ### Data scaling

# %%
for feature in df_train.columns:
    if (feature == targetSeries): continue

    # Setup scaler
    #
    scaler = RobustScaler()

    # Performing Scaling - for each feature
    df_train[feature] = scaler.fit_transform( df_train[feature].to_numpy().reshape(-1,1) )
    df_test[feature]  = scaler.transform( df_test[feature].to_numpy().reshape(-1,1) )


# Setup scaler
#
scaler = RobustScaler()

df_train[targetSeries] = scaler.fit_transform( df_train[targetSeries].to_numpy().reshape(-1,1) )
df_test[targetSeries]  = scaler.transform( df_test[targetSeries].to_numpy().reshape(-1,1) )

# %% [markdown]
# ### Create fitting data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, includeLagData = False, includeDate = False, overlap = 1):
    
    if (targetSeries is None):
        targetSeries = df.columns[-1]
    
    dataX, dataY, CurrentValue = [], [], []
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):
        
        # Original data
        data       = df.to_numpy()[i+1:(i+Lag)]        
        
        # Include date info
        if (includeDate):            
            myDate = [ np.sin(df[i+1:(i+Lag)].index.hour + df[i+1:(i+Lag)].index.minute / 60 ).tolist(), 
                       np.cos(df[i+1:(i+Lag)].index.hour + df[i+1:(i+Lag)].index.minute / 60 ).tolist() ]
            myDate = np.asarray( myDate ).T
            #
            # Concatenate data            
            data = np.concatenate([data, myDate], axis = -1)

        # data_diff: Lag-d differences
        if (includeLagData):
            data_diff  = (df.iloc[i+Lag-1] - df.iloc[i:(i+Lag-1)]).to_numpy()
            #
            # Concatenate data
            data = np.concatenate([data, data_diff], axis = -1)
                
        
        # Concatenate data
        dataX.append( data )
        
        
        # Current value
        CurrentValue.append( df[ targetSeries ].to_numpy()[i+Lag-1] )
        
        
        # Target Instance
        Instance = (df[ targetSeries ][i+Lag-1] - df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon])
        # Append instance
        dataY.append( Instance )        
        
    return ( np.array(dataX), np.array(dataY), np.array(CurrentValue) )

# %%
trainX, trainY, _ = create_dataset(df            = df_train, 
                                  Lag            = Lag, 
                                  Horizon        = Horizon, 
                                  targetSeries   = targetSeries,
                                  includeLagData = True,
                                  includeDate    = False,
                                  overlap        = Horizon)
                               

testX,  testY, test_CurrentValue = create_dataset(df             = df_test, 
                                                 Lag            = Lag, 
                                                 Horizon        = Horizon, 
                                                 targetSeries   = targetSeries,
                                                 includeLagData = True,
                                                 includeDate    = False,
                                                 overlap        = 1)


print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0] )
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4276/4276 [00:02<00:00, 1891.27it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4277/4277 [00:02<00:00, 2008.21it/s]
# Training instances:     4276
# Testing instances:      4277

# %%
trainX.shape, trainY.shape
# Out:
# ((4276, 11, 4), (4276, 4))

# %% [markdown]
# # Forecasting model

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## Setup model

# %%
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.models                  import *

# Inputs
#
Inputs = Input(shape = (trainX.shape[1], trainX.shape[2]))


# Encoder
#
Encoder = LSTM(units = 100, activation='relu')( Inputs )

# Decoder
#
Decoder = RepeatVector( Horizon )(Encoder)
#
Decoder = LSTM(units = 100, activation='relu')( Decoder )
#
# Output
#
Outputs = Dense( Horizon, activation='linear' )( Decoder )


# Create model
#
model = Model(inputs = Inputs, outputs = Outputs)

# from utils.Attention import *
# # https://github.com/philipperemy/keras-attention-mechanism


# model_input = Input(shape=( trainX.shape[1], trainX.shape[2]) )   


# x = Conv1D(filters=32, kernel_size=2, padding='same', activation='relu' )(model_input)
# x = MaxPool1D(2)(x)
# x = Conv1D(filters=64, kernel_size=2, padding='same', activation='relu' )(x)
# x = Attention(100)(x)
# #
# x = Dense(32)(x)
# x = BatchNormalization()(x)
# x = Dropout(0.2)(x)
  
# x = Dense(Horizon, activation='linear')(x)


# model = Model(model_input, x)
# Out:
# 2022-05-11 16:29:22.417369: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Training forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsoluteError(name = "MAE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]


model.compile(loss      = 'mse', 
              optimizer = Adam(learning_rate = 5.e-4), 
              metrics   = metrics)

# %%
# Checkpoint
#
checkpoint = ModelCheckpoint("models/SuperHybrid.hdf5", 
                              monitor        = 'val_loss', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 40)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_loss', 
                                   factor      = 0.5,
                                   patience    = 20)

# %%
# Start clock
#
start = timeit.default_timer()


score = model.fit(trainX, trainY, 
                  epochs          = epochs, 
                  batch_size      = batch_size, 
                  callbacks       = [checkpoint, earlystopping, lrs_scheduler],
                  verbose         = True, 
                  shuffle         = True,
                  validation_data = (testX, testY))


# Terminate clock
#
stop = timeit.default_timer()
# Out:
# Epoch 1/100
# 134/134 [==============================] - 2s 7ms/step - loss: 0.4933 - MAE: 0.5245 - RMSE: 0.7023 - val_loss: 0.1615 - val_MAE: 0.2712 - val_RMSE: 0.4019 - lr: 5.0000e-04
# Epoch 2/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3483 - MAE: 0.4439 - RMSE: 0.5902 - val_loss: 0.1707 - val_MAE: 0.2796 - val_RMSE: 0.4132 - lr: 5.0000e-04
# Epoch 3/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2201 - MAE: 0.3484 - RMSE: 0.4691 - val_loss: 0.1443 - val_MAE: 0.2526 - val_RMSE: 0.3798 - lr: 5.0000e-04
# Epoch 4/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.1201 - MAE: 0.2526 - RMSE: 0.3466 - val_loss: 0.1433 - val_MAE: 0.2522 - val_RMSE: 0.3786 - lr: 5.0000e-04
# Epoch 5/100
# 134/134 [==============================] - 1s 6ms/step - loss: 0.0886 - MAE: 0.2123 - RMSE: 0.2976 - val_loss: 0.1409 - val_MAE: 0.2544 - val_RMSE: 0.3753 - lr: 5.0000e-04
# Epoch 6/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0804 - MAE: 0.1977 - RMSE: 0.2835 - val_loss: 0.1376 - val_MAE: 0.2506 - val_RMSE: 0.3709 - lr: 5.0000e-04
# Epoch 7/100
# 134/134 [==============================] - 1s 6ms/step - loss: 0.0767 - MAE: 0.1914 - RMSE: 0.2769 - val_loss: 0.1337 - val_MAE: 0.2452 - val_RMSE: 0.3657 - lr: 5.0000e-04
# Epoch 8/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0745 - MAE: 0.1887 - RMSE: 0.2729 - val_loss: 0.1347 - val_MAE: 0.2583 - val_RMSE: 0.3670 - lr: 5.0000e-04
# Epoch 9/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0708 - MAE: 0.1822 - RMSE: 0.2661 - val_loss: 0.1328 - val_MAE: 0.2447 - val_RMSE: 0.3644 - lr: 5.0000e-04
# Epoch 10/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0694 - MAE: 0.1797 - RMSE: 0.2634 - val_loss: 0.1280 - val_MAE: 0.2410 - val_RMSE: 0.3578 - lr: 5.0000e-04
# Epoch 11/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0697 - MAE: 0.1788 - RMSE: 0.2640 - val_loss: 0.1305 - val_MAE: 0.2432 - val_RMSE: 0.3613 - lr: 5.0000e-04
# Epoch 12/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0686 - MAE: 0.1776 - RMSE: 0.2619 - val_loss: 0.1299 - val_MAE: 0.2329 - val_RMSE: 0.3604 - lr: 5.0000e-04
# Epoch 13/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0668 - MAE: 0.1753 - RMSE: 0.2585 - val_loss: 0.1361 - val_MAE: 0.2359 - val_RMSE: 0.3690 - lr: 5.0000e-04
# Epoch 14/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0671 - MAE: 0.1750 - RMSE: 0.2590 - val_loss: 0.1285 - val_MAE: 0.2334 - val_RMSE: 0.3585 - lr: 5.0000e-04
# Epoch 15/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0662 - MAE: 0.1731 - RMSE: 0.2572 - val_loss: 0.1404 - val_MAE: 0.2388 - val_RMSE: 0.3747 - lr: 5.0000e-04
# Epoch 16/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0653 - MAE: 0.1724 - RMSE: 0.2555 - val_loss: 0.1327 - val_MAE: 0.2375 - val_RMSE: 0.3643 - lr: 5.0000e-04
# Epoch 17/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0648 - MAE: 0.1716 - RMSE: 0.2546 - val_loss: 0.1273 - val_MAE: 0.2323 - val_RMSE: 0.3568 - lr: 5.0000e-04
# Epoch 18/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0639 - MAE: 0.1707 - RMSE: 0.2528 - val_loss: 0.1262 - val_MAE: 0.2317 - val_RMSE: 0.3552 - lr: 5.0000e-04
# Epoch 19/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0635 - MAE: 0.1696 - RMSE: 0.2520 - val_loss: 0.1281 - val_MAE: 0.2385 - val_RMSE: 0.3579 - lr: 5.0000e-04
# Epoch 20/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0640 - MAE: 0.1699 - RMSE: 0.2530 - val_loss: 0.1310 - val_MAE: 0.2587 - val_RMSE: 0.3619 - lr: 5.0000e-04
# Epoch 21/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0636 - MAE: 0.1701 - RMSE: 0.2521 - val_loss: 0.1263 - val_MAE: 0.2321 - val_RMSE: 0.3554 - lr: 5.0000e-04
# Epoch 22/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0632 - MAE: 0.1698 - RMSE: 0.2513 - val_loss: 0.1283 - val_MAE: 0.2333 - val_RMSE: 0.3583 - lr: 5.0000e-04
# Epoch 23/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0627 - MAE: 0.1689 - RMSE: 0.2505 - val_loss: 0.1344 - val_MAE: 0.2656 - val_RMSE: 0.3666 - lr: 5.0000e-04
# Epoch 24/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0628 - MAE: 0.1697 - RMSE: 0.2506 - val_loss: 0.1280 - val_MAE: 0.2361 - val_RMSE: 0.3577 - lr: 5.0000e-04
# Epoch 25/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0622 - MAE: 0.1679 - RMSE: 0.2494 - val_loss: 0.1258 - val_MAE: 0.2398 - val_RMSE: 0.3547 - lr: 5.0000e-04
# Epoch 26/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0611 - MAE: 0.1656 - RMSE: 0.2472 - val_loss: 0.1790 - val_MAE: 0.2759 - val_RMSE: 0.4231 - lr: 5.0000e-04
# Epoch 27/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0623 - MAE: 0.1673 - RMSE: 0.2496 - val_loss: 0.1492 - val_MAE: 0.2541 - val_RMSE: 0.3862 - lr: 5.0000e-04
# Epoch 28/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0615 - MAE: 0.1672 - RMSE: 0.2479 - val_loss: 0.1257 - val_MAE: 0.2315 - val_RMSE: 0.3546 - lr: 5.0000e-04
# Epoch 29/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0598 - MAE: 0.1648 - RMSE: 0.2445 - val_loss: 0.1342 - val_MAE: 0.2370 - val_RMSE: 0.3664 - lr: 5.0000e-04
# Epoch 30/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0601 - MAE: 0.1647 - RMSE: 0.2451 - val_loss: 0.1293 - val_MAE: 0.2529 - val_RMSE: 0.3596 - lr: 5.0000e-04
# Epoch 31/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0598 - MAE: 0.1651 - RMSE: 0.2445 - val_loss: 0.1349 - val_MAE: 0.2409 - val_RMSE: 0.3673 - lr: 5.0000e-04
# Epoch 32/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0590 - MAE: 0.1630 - RMSE: 0.2429 - val_loss: 0.1361 - val_MAE: 0.2404 - val_RMSE: 0.3690 - lr: 5.0000e-04
# Epoch 33/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0589 - MAE: 0.1628 - RMSE: 0.2427 - val_loss: 0.1317 - val_MAE: 0.2500 - val_RMSE: 0.3629 - lr: 5.0000e-04
# Epoch 34/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0589 - MAE: 0.1627 - RMSE: 0.2427 - val_loss: 0.1432 - val_MAE: 0.2724 - val_RMSE: 0.3784 - lr: 5.0000e-04
# Epoch 35/100
# 134/134 [==============================] - 1s 5ms/step - loss: 0.0589 - MAE: 0.1636 - RMSE: 0.2426 - val_loss: 0.1348 - val_MAE: 0.2383 - val_RMSE: 0.3671 - lr: 5.0000e-04
# Epoch 36/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0578 - MAE: 0.1608 - RMSE: 0.2404 - val_loss: 0.1308 - val_MAE: 0.2508 - val_RMSE: 0.3616 - lr: 5.0000e-04
# Epoch 37/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0584 - MAE: 0.1625 - RMSE: 0.2416 - val_loss: 0.1295 - val_MAE: 0.2494 - val_RMSE: 0.3598 - lr: 5.0000e-04
# Epoch 38/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0579 - MAE: 0.1622 - RMSE: 0.2407 - val_loss: 0.1317 - val_MAE: 0.2528 - val_RMSE: 0.3630 - lr: 5.0000e-04
# Epoch 39/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0582 - MAE: 0.1622 - RMSE: 0.2413 - val_loss: 0.1282 - val_MAE: 0.2420 - val_RMSE: 0.3580 - lr: 5.0000e-04
# Epoch 40/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0576 - MAE: 0.1613 - RMSE: 0.2400 - val_loss: 0.1325 - val_MAE: 0.2351 - val_RMSE: 0.3640 - lr: 5.0000e-04
# Epoch 41/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0576 - MAE: 0.1611 - RMSE: 0.2400 - val_loss: 0.1399 - val_MAE: 0.2668 - val_RMSE: 0.3740 - lr: 5.0000e-04
# Epoch 42/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0567 - MAE: 0.1601 - RMSE: 0.2380 - val_loss: 0.1456 - val_MAE: 0.2813 - val_RMSE: 0.3816 - lr: 5.0000e-04
# Epoch 43/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0570 - MAE: 0.1614 - RMSE: 0.2388 - val_loss: 0.1298 - val_MAE: 0.2300 - val_RMSE: 0.3603 - lr: 5.0000e-04
# Epoch 44/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0554 - MAE: 0.1589 - RMSE: 0.2353 - val_loss: 0.1565 - val_MAE: 0.2885 - val_RMSE: 0.3956 - lr: 5.0000e-04
# Epoch 45/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0569 - MAE: 0.1608 - RMSE: 0.2385 - val_loss: 0.1357 - val_MAE: 0.2342 - val_RMSE: 0.3684 - lr: 5.0000e-04
# Epoch 46/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0547 - MAE: 0.1573 - RMSE: 0.2339 - val_loss: 0.1303 - val_MAE: 0.2415 - val_RMSE: 0.3610 - lr: 2.5000e-04
# Epoch 47/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0536 - MAE: 0.1562 - RMSE: 0.2315 - val_loss: 0.1321 - val_MAE: 0.2394 - val_RMSE: 0.3635 - lr: 2.5000e-04
# Epoch 48/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0530 - MAE: 0.1552 - RMSE: 0.2302 - val_loss: 0.1345 - val_MAE: 0.2433 - val_RMSE: 0.3667 - lr: 2.5000e-04
# Epoch 49/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0534 - MAE: 0.1566 - RMSE: 0.2311 - val_loss: 0.1341 - val_MAE: 0.2379 - val_RMSE: 0.3663 - lr: 2.5000e-04
# Epoch 50/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0535 - MAE: 0.1558 - RMSE: 0.2313 - val_loss: 0.1326 - val_MAE: 0.2391 - val_RMSE: 0.3641 - lr: 2.5000e-04
# Epoch 51/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0532 - MAE: 0.1557 - RMSE: 0.2306 - val_loss: 0.1351 - val_MAE: 0.2520 - val_RMSE: 0.3676 - lr: 2.5000e-04
# Epoch 52/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0527 - MAE: 0.1559 - RMSE: 0.2296 - val_loss: 0.1368 - val_MAE: 0.2510 - val_RMSE: 0.3699 - lr: 2.5000e-04
# Epoch 53/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0520 - MAE: 0.1549 - RMSE: 0.2281 - val_loss: 0.1352 - val_MAE: 0.2444 - val_RMSE: 0.3677 - lr: 2.5000e-04
# Epoch 54/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0526 - MAE: 0.1557 - RMSE: 0.2293 - val_loss: 0.1342 - val_MAE: 0.2393 - val_RMSE: 0.3663 - lr: 2.5000e-04
# Epoch 55/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0523 - MAE: 0.1547 - RMSE: 0.2287 - val_loss: 0.1331 - val_MAE: 0.2500 - val_RMSE: 0.3649 - lr: 2.5000e-04
# Epoch 56/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0521 - MAE: 0.1542 - RMSE: 0.2282 - val_loss: 0.1333 - val_MAE: 0.2421 - val_RMSE: 0.3651 - lr: 2.5000e-04
# Epoch 57/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0513 - MAE: 0.1533 - RMSE: 0.2265 - val_loss: 0.1395 - val_MAE: 0.2521 - val_RMSE: 0.3734 - lr: 2.5000e-04
# Epoch 58/100
# 134/134 [==============================] - 1s 4ms/step - loss: 0.0519 - MAE: 0.1545 - RMSE: 0.2277 - val_loss: 0.1353 - val_MAE: 0.2403 - val_RMSE: 0.3678 - lr: 2.5000e-04
# Epoch 59/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0520 - MAE: 0.1545 - RMSE: 0.2279 - val_loss: 0.1334 - val_MAE: 0.2472 - val_RMSE: 0.3652 - lr: 2.5000e-04
# Epoch 60/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0512 - MAE: 0.1535 - RMSE: 0.2263 - val_loss: 0.1436 - val_MAE: 0.2451 - val_RMSE: 0.3789 - lr: 2.5000e-04
# Epoch 61/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0517 - MAE: 0.1540 - RMSE: 0.2274 - val_loss: 0.1381 - val_MAE: 0.2418 - val_RMSE: 0.3716 - lr: 2.5000e-04
# Epoch 62/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0510 - MAE: 0.1531 - RMSE: 0.2259 - val_loss: 0.1374 - val_MAE: 0.2514 - val_RMSE: 0.3706 - lr: 2.5000e-04
# Epoch 63/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0508 - MAE: 0.1523 - RMSE: 0.2255 - val_loss: 0.1376 - val_MAE: 0.2458 - val_RMSE: 0.3709 - lr: 2.5000e-04
# Epoch 64/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0503 - MAE: 0.1518 - RMSE: 0.2242 - val_loss: 0.1426 - val_MAE: 0.2456 - val_RMSE: 0.3776 - lr: 2.5000e-04
# Epoch 65/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0508 - MAE: 0.1532 - RMSE: 0.2254 - val_loss: 0.1355 - val_MAE: 0.2402 - val_RMSE: 0.3681 - lr: 2.5000e-04
# Epoch 66/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0489 - MAE: 0.1492 - RMSE: 0.2212 - val_loss: 0.1377 - val_MAE: 0.2485 - val_RMSE: 0.3711 - lr: 1.2500e-04
# Epoch 67/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0487 - MAE: 0.1503 - RMSE: 0.2207 - val_loss: 0.1388 - val_MAE: 0.2493 - val_RMSE: 0.3726 - lr: 1.2500e-04
# Epoch 68/100
# 134/134 [==============================] - 0s 4ms/step - loss: 0.0491 - MAE: 0.1503 - RMSE: 0.2216 - val_loss: 0.1435 - val_MAE: 0.2483 - val_RMSE: 0.3788 - lr: 1.2500e-04
# Epoch 00068: early stopping

# %%
# Create figure
#
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 3) )

# Plot RMSE
#
ax[0].plot( score.history['RMSE'], marker = 'o');
ax[0].plot( score.history['val_RMSE'], marker = 'o');
ax[0].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[0].set_title('RMSE');

# Plot RMSE
#
ax[1].plot( score.history['MAE'], marker = 'o');
ax[1].plot( score.history['val_MAE'], marker = 'o');
ax[1].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[1].set_title('MAE');

# %% [markdown]
# ## Load optimized forecasting model

# %%
# Load the best model
#
model.load_weights('models/SuperHybrid.hdf5')

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Get predictions

# %%
# Get predictions
#
pred = model.predict( testX )

# %% [markdown]
# ## Inverse "Lag-d Diff" transformation

# %%
for i in range( Horizon ):
    testY[:, i] = test_CurrentValue - testY[:, i]
    pred[:, i]  = test_CurrentValue - pred[:, i]

# %% [markdown]
# ## Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred  = np.exp( pred )  - VALUE

# %% [markdown]
# ## Visualization of predictions

# %%
Results = dict()

for i in range( Horizon ):
    Prices = pd.DataFrame( [] )

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]
    

        
    # Store results
    #
    Results[ 'Horizon {}'.format(i+1) ] = Prices

    
    
    
    # Plot results
    #
    plt.figure( figsize = (20, 4) );
    #
    Prices[ targetSeries ][:100].plot(color = 'tab:blue',   marker = 'o')
    Prices[ 'Prediction' ][:100].plot(color = 'tab:orange', marker = 'o')
    
    #
    #
    plt.legend([targetSeries, 'Prediction'], fontsize = 12, frameon=False);
    plt.ylabel(targetSeries, size = 12 );
    plt.xlabel('Time', size = 12);
    plt.show()

# %% [markdown]
# ## Regression evaluation

# %%
sResults = {'MAE': [], 'RMSE': [], 'MAPE': [], 'SMAPE': [], 'R2': []}

for i in range(Horizon):
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Results['Horizon {}'.format(i+1)] )
    
    sResults['MAE']   += [MAE]
    sResults['RMSE']  += [RMSE]
    sResults['MAPE']  += [MAPE]
    sResults['SMAPE'] += [SMAPE]
    sResults['R2']    += [R2]
    
    
#     print('Horizon -%i-' % (i+1))
#     print('--------------')
#     print('MAE   = %.3f' % MAE)
#     print('RMSE  = %.3f' % RMSE)
#     print('MAPE  = %.3f' % MAPE)
#     print('SMAPE = %.3f' % SMAPE)
#     print('R2    = %.3f' % R2)
#     print()
    print('Horizon: %2i MAE %5.2f SMAPE: %5.2f R2: %.2f' %(i+1, MAE, SMAPE, R2) )
# Out:
# Horizon:  1 MAE  9.89 SMAPE:  4.80 R2: 0.94
# Horizon:  2 MAE 17.58 SMAPE:  8.54 R2: 0.82
# Horizon:  3 MAE 22.49 SMAPE: 10.99 R2: 0.71
# Horizon:  4 MAE 26.52 SMAPE: 13.05 R2: 0.60

# %%
# NBeats + d-Lag
# Horizon:  1 MAE  9.76 SMAPE:  4.72 R2: 0.94
# Horizon:  2 MAE 17.16 SMAPE:  8.30 R2: 0.81
# Horizon:  3 MAE 22.07 SMAPE: 10.72 R2: 0.69
# Horizon:  4 MAE 26.25 SMAPE: 12.78 R2: 0.58

# CO (d-Lag+Value) - Log+StandardScaler
# ------------------------------------------------


# CO + NO2 (d-Lag+Value) - Log+StandardScaler
# ------------------------------------------------
# Horizon:  1 MAE  9.83 SMAPE:  4.78 R2: 0.94
# Horizon:  2 MAE 17.29 SMAPE:  8.46 R2: 0.82
# Horizon:  3 MAE 22.48 SMAPE: 11.12 R2: 0.71
# Horizon:  4 MAE 26.68 SMAPE: 13.29 R2: 0.62


# CO + NO2 (d-Lag+Value) - Log+RobustScaler
# ------------------------------------------------
# Horizon:  1 MAE  9.76 SMAPE:  4.75 R2: 0.94
# Horizon:  2 MAE 17.15 SMAPE:  8.39 R2: 0.82
# Horizon:  3 MAE 22.37 SMAPE: 11.07 R2: 0.72
# Horizon:  4 MAE 26.49 SMAPE: 13.19 R2: 0.62

# CO + NO2 (d-Lag+Value) Lag = 16 - Log+RobustScaler
# ------------------------------------------------
# Horizon:  1 MAE  9.77 SMAPE:  4.77 R2: 0.94
# Horizon:  2 MAE 17.37 SMAPE:  8.52 R2: 0.82
# Horizon:  3 MAE 22.38 SMAPE: 11.02 R2: 0.71
# Horizon:  4 MAE 26.46 SMAPE: 13.12 R2: 0.61

# %%
# print('[INFO] Feature: ', targetSeries)
# print('------------------------------------------------')
# Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

# for i in range( Horizon ):

#     Prices[targetSeries] = testY[:,i]
#     Prices['Prediction'] = pred[:,i]
    
            
#     from scipy import stats
#     from statsmodels.graphics.tsaplots import plot_acf
    
#     res = (Prices[targetSeries] - Prices['Prediction']).to_numpy()
    
#     fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

#     ax[0].hist( res, bins = 100 )    
#     plot_acf( res, ax=ax[1] )

# %% [markdown]
# ## Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )  
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]
RandomInstances = [913, 205, 2254, 2007, 1829, 1144, 840, 713, 3457]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    #
    plt.plot(range(Lag, Lag + Horizon), testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(range(Lag, Lag + Horizon), pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Instance', 'Future values', 'Prediction'], frameon = False, fontsize = 12)
plt.show()

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame( [] )


Outputs[ targetSeries ] = testY.flatten()
Outputs['Hybrid']       = pred.flatten()

Outputs.to_csv('Predictions/SuperHybrid.csv')
